# #### Tras comprobar que los resultados están estabilizados y bastante bien regularizados (batch normalization, dropout, class_weight...). Añadir L2 o pequeños cambios de dropout no aporta grandes mejoras en Test.
# #### Se puede decir que el modelo:
# * #### Aprende
# * #### Generaliza
# * #### No sobreajusta
#
# #### Aparentemente no se trata de regularizar más, sino de hacer que el modelo vea mejores datos, o más variados y representativos. Es por eso que intentamos con una técnica de Data Augmentation mas avanzada.
# #### **MixUp:** Mezcla 2 imágenes sumándolas y promedia las etiquetas.

# %%
"""
def mixup_generator(generator, alpha=0.2):
    while True:
        x, y = next(generator)
        if len(y.shape) == 1:
            y = np.expand_dims(y, axis=-1)
        batch_size = x.shape[0]
        indices = np.random.permutation(batch_size)
        x2, y2 = x[indices], y[indices]

        lam = np.random.beta(alpha, alpha, batch_size) 
        lam_x = lam.reshape(batch_size, 1, 1, 1)
        lam_y = lam.reshape(batch_size, 1)

        x_mix = x * lam_x + x2 * (1 - lam_x)
        y_mix = y * lam_y + y2 * (1 - lam_y) 

        yield x_mix, y_mix
"""

# %% [markdown]
# ## **DEPRECATED: Carga de imágenes, etiquetado & Data Augmentation**
# #### > No permite la partición aleatorizada de datos.
# #### > División: 80% Train 20% Val. Keras escoge automáticamente ese 20% de imágenes y lo hace en base al orden alfabético de los archivos, no al azar.
# #### > Por lo que da siempre la misma partición de datos.

# %% [markdown]
# #### En este punto:
# * Se cargan las imágenes directamente desde carpetas, y se les asigna automáticamente una etiqueta según su clase (NORMAL o NEUMONÍA)
# * Las imágenes se normalizan a valores entre 0 y 1
# * Al conjunto de entrenamiento se le aplican técnicas de Data Augmentation para mejorar la generalización del modelo
#
# #### Técnicas de Data Augmentation aplicadas (solo en entrenamiento):
# * Rotación aleatoria de hasta 16 grados
# * Zoom aleatorio de hasta un 10%
# * Desplazamiento horizontal aleatorio del 2% del ancho
# * Desplazamiento vertical aleatorio del 2% de la altura
# * Inclinación (shear) de hasta 0.03 radianes
# * Volteo horizontal aleatorio
#
# #### Se ha divido el conjunto de entrenamiento, para pasar imágenes desde este conjunto al de validación, pues originalmente validación sólo contenia 16 imágenes.
# #### Dejándolo en una proporción de 80/20.

# %%
"""
img_size = 150
batch_size = 64

# Definición de ImageDataGenerator para entrenamiento con Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,                                         # Dividimos el contenido de train en 80/20
    rotation_range=16,         
    zoom_range=0.1,           
    width_shift_range=0.02,    
    height_shift_range=0.02,   
    shear_range=0.03,      
    horizontal_flip=True
)

# Definición de ImageDataGenerator para test sin aplicar aumentos, solo normaliza. 
test_datagen = ImageDataGenerator(rescale=1./255)

# Cargar el dataset de entrenamiento
train_generator = train_datagen.flow_from_directory(
    '../input/chest-xray-pneumonia/chest_xray/train',            # Cargamos las imagenes 
    target_size=(img_size, img_size),                            
    color_mode='rgb',                                            # Las imágenes originales estan en escala de grises. Esto replica el canal de grises 3 veces, para poder usar modelos preentrenados en ImageNet.
    batch_size=batch_size,                                       
    class_mode='binary',                                         # Se etiquetan automáticamente como 0 o 1
    subset='training',                                           # Toma el 80% de las imágenes. Y aplica data augmentations
    shuffle=True                                                 # Las imágenes se mezclan aleatoriamente
)

# Cargar el dataset de validación
val_generator = train_datagen.flow_from_directory(
    '../input/chest-xray-pneumonia/chest_xray/train',            # Se usa la misma carpeta train (y train_datagen)
    target_size=(img_size, img_size),
    color_mode='rgb',
    batch_size=batch_size,
    class_mode='binary',
    subset='validation',                                         # Se extrae el otro 20%. Keras desactiva automáticamente todos los augmentations
    shuffle=False                                                # No aplica
)

# Cargar el dataset de test
test_generator = test_datagen.flow_from_directory(
    '../input/chest-xray-pneumonia/chest_xray/test',
    target_size=(img_size, img_size),
    color_mode='rgb',
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)

# train_mixup_generator = mixup_generator(train_generator, alpha=0.15)
"""

# %% [markdown]
# #### Dataset original:
# * #### Entrenamiento -> 5216 imágenes
# * #### Validación -> 16 imágenes
# * #### Test -> 624 imágenes
#
# #### Partiendo el conjunto de Entrenamiento en 80/20 para darle mas imágenes a Validación (despreciando las 16 imágenes que contenia), queda finalmente:
# * #### Entrenamiento -> 4173 imágenes
# * #### Validación -> 1043 imágenes
# * #### Test -> 624 imágenes

# %% [markdown]
# ## **Carga de imágenes, etiquetado & Data Augmentation V2**

# %%
# ======================
# RUTAS AL DATASET
# ======================
train_dir = '../input/chest-xray-pneumonia/chest_xray/train'
test_dir = '../input/chest-xray-pneumonia/chest_xray/test'
val_dir = '../input/chest-xray-pneumonia/chest_xray/val'

# ============================
# CARGAR IMÁGENES Y ETIQUETAS
# ============================
def get_image_paths_labels(data_dir):
    categories = ['NORMAL', 'PNEUMONIA']
    image_paths = []
    labels = []
    
    for category in categories:
        folder_path = os.path.join(data_dir, category)
        for img in os.listdir(folder_path):
            if img.lower().endswith(('.jpg', '.jpeg')):
                image_paths.append(os.path.join(folder_path, img))
                labels.append(category)
    
    return image_paths, labels

# %%
# ======================
# DATAFRAMES PARA TEST
# ======================
test_paths, test_labels = get_image_paths_labels(test_dir)
test_df = pd.DataFrame({'filename': test_paths, 'label': test_labels})

# =======================
# DATAFRAMES Y PARTICIÓN
# =======================
def get_dataframes(train_dir, val_dir, seed=0):
    train_paths, train_labels = get_image_paths_labels(train_dir)
    val_paths, val_labels = get_image_paths_labels(val_dir)

    # Unimos train + val
    all_paths = train_paths + val_paths
    all_labels = train_labels + val_labels
    
    df = pd.DataFrame({'filename': all_paths, 'label': all_labels})

    # Split 80/20
    train_df, val_df = train_test_split(df, test_size=0.2, stratify=df['label'], random_state=seed)

    return train_df, val_df

# %%
# ================================
# DATA AUGMENTATION Y GENERADORES
# ================================
def get_data_generators(train_df, val_df, test_df, img_size=150, batch_size=64, seed=0):
    # Data Augmentation 
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=25,
        zoom_range=0.1,
        width_shift_range=0.04,
        height_shift_range=0.04,
        brightness_range=(0.9, 1.1),
        horizontal_flip=True,
        fill_mode='nearest'
    )

    val_test_datagen = ImageDataGenerator(rescale=1./255)

    train_generator = train_datagen.flow_from_dataframe(
        train_df,
        directory=None, 
        x_col='filename',
        y_col='label',
        target_size=(img_size, img_size),
        color_mode='rgb',
        batch_size=batch_size,
        class_mode='binary',
        shuffle=True,
        seed=seed
    )

    val_generator = val_test_datagen.flow_from_dataframe(
        val_df,
        directory=None, 
        x_col='filename',
        y_col='label',
        target_size=(img_size, img_size),
        color_mode='rgb',
        batch_size=batch_size,
        class_mode='binary',
        shuffle=False
    )

    test_generator = val_test_datagen.flow_from_dataframe(
        test_df,
        directory=None, 
        x_col='filename',
        y_col='label',
        target_size=(img_size, img_size),
        color_mode='rgb',
        batch_size=batch_size,
        class_mode='binary',
        shuffle=False
    )  
    
    return train_generator, val_generator, test_generator

# %%
train_df, val_df = get_dataframes(train_dir, val_dir, seed=0)
train_generator, val_generator, test_generator = get_data_generators(train_df, val_df, test_df, img_size=150, batch_size=64, seed=0)
# Out:
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.

# %% [markdown]
# #### Dataset original:
# * #### Entrenamiento -> 5216 imágenes
# * #### Validación -> 16 imágenes
# * #### Test -> 624 imágenes
# #### Total = 5856 imágenes
#
# #### Hemos juntado Entrenamiento y Validación, para después dividirlo en la proporción: 80% y 20% respectivamente. De este modo no hemos perdido niguna imagen del dataset.
# * #### Entrenamiento -> 4185 imágenes
# * #### Validación -> 1047 imágenes
# * #### Test -> 624 imágenes
# #### Total = 5856 imágenes
#
# #### Aplicar Data Augmentation no aumenta el numero total de imágenes del dataset en disco, sino que las modifica "al vuelo" cada vez que se entrena el modelo, es decir, en memoria.
# #### Una imagen puede ser rotada en la primera época, y en la segunda época esa misma imagen aplicar un desplazamiento, o zoom.
#
# #### Por lo tanto, podemos estimar el numero de imágenes que el modelo ve (recordemos que son variaciones distintas de una misma imagen) segun el número de épocas que hayamos definido.

# %%
n_original = len(train_generator.filenames)
print(f"Número de imágenes originales: {n_original}")

n_epochs = 25
print(f"Imágenes vistas por el modelo durante {n_epochs} épocas (estimación): {n_epochs * n_original}")
# Out:
# Número de imágenes originales: 4185
# Imágenes vistas por el modelo durante 25 épocas (estimación): 104625

# %% [markdown]
# ## **Previsualización de imágenes**

# %%
label_map = {v: k for k, v in train_generator.class_indices.items()}
images, labels = next(train_generator)
shown_classes = set()

for i in range(len(images)):
    class_label = int(labels[i])
    if class_label not in shown_classes:
        plt.figure(figsize=(4, 4))
        plt.imshow(images[i].squeeze(), cmap='gray')
        plt.title(f"Ejemplo de clase: {label_map[class_label]}")
        plt.axis('off')
        plt.show()
        shown_classes.add(class_label)
    if len(shown_classes) == 2:
        break

# %% [markdown]
# ## **Muestreo de cada clase**
# #### > Nos centramos en analizar el **conjunto de Entrenamiento**, pues es donde el modelo aprende. Si hay un desbalanceo aqui, el modelo puede aprender un sesgo hacia la clase mayoritaria.
# #### > **Validación y Test** se usan tal y como están, sin balancear. El objetivo es evaluar la capacidad real del modelo en un entorno natural, donde los datos pueden venir desbalanceados.

# %% [markdown]
# #### Como se puede observar en la gráfica, el conjunto de datos de Entrenamiento está desbalanceado: hay muchas más imágenes de **neumonía** que de **normal**.
# #### El uso de **Data Augmentation** ayuda a reducir el sobreajuste (overfitting), favoreciendo el aprendizaje de patrones más robustos y generalizables.
# #### Sin embargo, en este caso se ha aplicado por igual a ambas clases, lo que no corrige el desbalanceo, sino que mantiene el sesgo hacia la clase mayoritaria (neumonía), facilitando que el modelo tienda a predecirla con mayor frecuencia.
# #### Alternativas comunes para abordar este desbalanceo:
# * #### Aplicar data augmentation solo sobre la clase minoritaria (normal).
# * #### Utilizar el parámetro *class_weight* durante el entrenamiento para dar más importancia a la clase menos representada.

# %%
def class_distribution_counts(generator, title):
    labels = generator.classes
    label_map = {v: k for k, v in generator.class_indices.items()}
    counts = Counter(labels)

    print(f"\n{title}")
    for k, v in counts.items():
        print(f"{label_map[k]}: {v} imágenes")
    return counts

train_counts = class_distribution_counts(train_generator, "Distribución en Entrenamiento")
val_counts   = class_distribution_counts(val_generator, "Distribución en Validación")
test_counts  = class_distribution_counts(test_generator, "Distribución en Test")
# Out:
# Distribución en Entrenamiento
# PNEUMONIA: 3106 imágenes
# NORMAL: 1079 imágenes
#
# Distribución en Validación
# PNEUMONIA: 777 imágenes
# NORMAL: 270 imágenes
#
# Distribución en Test
# NORMAL: 234 imágenes
# PNEUMONIA: 390 imágenes

# %%
def class_distribution(generator, title):
    labels = generator.classes
    label_map = {v: k for k, v in generator.class_indices.items()}
    label_names = [label_map[i] for i in labels]
    label_names = pd.Categorical(label_names, categories=['PNEUMONIA', 'NORMAL'], ordered=True)

    sns.set_style("darkgrid")
    plt.figure(figsize=(6, 4))
    sns.countplot(x=pd.Series(label_names))
    plt.title(title)
    plt.xlabel("Clase")
    plt.ylabel("Número de Imágenes")
    plt.show()

class_distribution(train_generator, "Distribución de Clases en el Conjunto de Entrenamiento")
class_distribution(val_generator, "Distribución de Clases en el Conjunto de Validación")
class_distribution(test_generator, "Distribución de Clases en el Conjunto de Test")

# %% [markdown]
# ## **Ajuste al desbalanceo de clases**

# %% [markdown]
# #### Hemos aplicado ***class_weight*** para compensar el desequilibrio entre clases durante el entrenamiento de forma sencilla y efectiva.
# #### Que hemos conseguido:
# * #### Penalizamos más los errores en la clase minoritaria (**NORMAL**).
# * #### Mejora el **recall** (sensibilidad) para dicha clase.
# * #### Ayuda a evitar un sesgo hacia la clase mayoritaria (**PNEUMONIA**).
# * #### El ajuste se aplica directamente en la función de pérdida, sin alterar los datos de entrada.
#
# #### Los pesos se calculan automáticamente con **balanced**, que aplica: *class_weight = N_total / (N_clase * N_clases)*

# %%
def get_class_weights(train_df):
    y_train = train_df['label']
    classes = np.unique(y_train)
    
    weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
    class_weights = dict(zip(classes, weights))
    return class_weights

class_weights = get_class_weights(train_df)
print("Pesos de las clases:", class_weights)
# Out:
# Pesos de las clases: {'NORMAL': 1.9392956441149212, 'PNEUMONIA': 0.6736960721184804}

# %% [markdown]
# # **Callbacks Globales para el Entrenamiento**

# %%
def get_callbacks():
    early_stopping = EarlyStopping(
        monitor='val_auc',
        patience=10,
        restore_best_weights=True,
        mode='max',
        verbose=1
    )

    reduce_learning_rate = ReduceLROnPlateau(
        monitor='val_auc',
        patience=2,
        factor=0.3,
        min_lr=1e-5,
        mode='max',
        verbose=1
    )

    return [early_stopping, reduce_learning_rate]

callbacks = get_callbacks()
print("Callbacks usados:")
for callback in callbacks:
    print(" -", type(callback).__name__)
# Out:
# Callbacks usados:
#  - EarlyStopping
#  - ReduceLROnPlateau

# %% [markdown]
# # **Entrenamiento Desde Cero**

# %% [markdown]
# ## **Entrenamiento del Modelo 1: Custom CNN**

# %% [markdown]
# ### Arquitectura

# %%
def build_custom_cnn(img_size=150, learning_rate=0.0005):
    model = Sequential([
        Input(shape=(img_size, img_size, 3)),

        Conv2D(32, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(32, (3, 3), activation='relu', padding='same'),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.2),

        Conv2D(64, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.2),

        Conv2D(128, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.3),

        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.6),
        Dense(1, activation='sigmoid')
    ])

    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(learning_rate=learning_rate),
        metrics=['accuracy', AUC(name='auc')]
    )

    return model
    
model_cnn = build_custom_cnn()
model_cnn.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)                    │ (None, 150, 150, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 150, 150, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 150, 150, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 75, 75, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 75, 75, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 75, 75, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 75, 75, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 75, 75, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 37, 37, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 37, 37, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 37, 37, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 37, 37, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 37, 37, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 18, 18, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 18, 18, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 41472)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │       5,308,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,596,577 (21.35 MB)
#  Trainable params: 5,596,129 (21.35 MB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# 1. **Output Shape:** tamaño del tensor de salida (número de características o mapas de activación que salen de cada capa)
# 2. **Param #:** Cantidad de parámetros entrenables en cada capa (es decir, los pesos que el modelo aprende)
#     1. **En capas Conv2D:** (kernel_height × kernel_width × input_channels × output_filters) + output_filters || Ejemplo: 3 × 3 × 3 × 32 + 32 = 896
#     2. **En capas Dense:** (input_neurons × output_neurons) + output_neurons || Ejemplo: 41.472 × 128 + 128 = 5.308.544

# %% [markdown]
# ### Entrenamiento

# %%
img_size = 150
batch_size = 64
learning_rate=0.0005
seeds = [0, 1, 2, 3, 4]

results_list = []
histories = {}
models = {}

test_paths, test_labels = get_image_paths_labels(test_dir)
test_df = pd.DataFrame({'filename': test_paths, 'label': test_labels})

for seed in seeds:
    print(f"\n=== SEMILLA {seed} ===")

    tf.random.set_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    
    # Preparar datos
    train_df, val_df = get_dataframes(train_dir, val_dir, seed)
    train_generator, val_generator, test_generator = get_data_generators(train_df, val_df, test_df, img_size, batch_size, seed)
    
    # Ajuste de pesos
    class_weights = get_class_weights(train_df)
    
    # Crear modelo Custom CNN
    model_cnn = build_custom_cnn(img_size, learning_rate)
    
    # Callbacks
    callbacks = get_callbacks()
    
    # Entrenamiento
    history = model_cnn.fit(
        train_generator,
        validation_data=val_generator,
        epochs=25,
        class_weight=class_weights,
        callbacks=callbacks,
    )
    
    histories[seed] = history
    models[seed] = model_cnn
    
    # Evaluación en test
    results = model_cnn.evaluate(test_generator, verbose=0)
    print(f"Test Loss: {results[0]:.4f}")
    print(f"Test Accuracy: {results[1]:.4f}")
    print(f"AUC: {results[2]:.4f}")
    
    # Guardar resultados
    results_list.append({
        'Seed': seed,
        'Test Loss': results[0],
        'Test Accuracy': results[1],
        'Test AUC': results[2]
    })

# Mostramos resultados
df_results = pd.DataFrame(results_list)

plt.figure(figsize=(8, 6))
sns.boxplot(data=df_results[['Test Accuracy', 'Test AUC', 'Test Loss']])
plt.title('Distribución de métricas en test (5 semillas)')
plt.grid(True)
plt.show()
# Out:
# === SEMILLA 0 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1754743836.744010    6339 service.cc:148] XLA service 0x7b5c0c007360 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1754743836.744054    6339 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1754743836.744061    6339 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1754743837.304325    6339 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  1/66 ━━━━━━━━━━━━━━━━━━━━ 22:37 21s/step - accuracy: 0.6406 - auc: 0.6000 - loss: 0.8108
# I0000 00:00:1754743851.241001    6339 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - accuracy: 0.6776 - auc: 0.6006 - loss: 2.7604 - val_accuracy: 0.7421 - val_auc: 0.6712 - val_loss: 0.8989 - learning_rate: 5.0000e-04
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 949ms/step - accuracy: 0.8513 - auc: 0.9285 - loss: 0.2958 - val_accuracy: 0.7421 - val_auc: 0.5102 - val_loss: 1.2341 - learning_rate: 5.0000e-04
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 817ms/step - accuracy: 0.8970 - auc: 0.9503 - loss: 0.2460
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 947ms/step - accuracy: 0.8970 - auc: 0.9503 - loss: 0.2460 - val_accuracy: 0.7421 - val_auc: 0.4981 - val_loss: 1.7945 - learning_rate: 5.0000e-04
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 944ms/step - accuracy: 0.9144 - auc: 0.9632 - loss: 0.2264 - val_accuracy: 0.7421 - val_auc: 0.5000 - val_loss: 2.9154 - learning_rate: 1.5000e-04
# Epoch 5/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 808ms/step - accuracy: 0.9377 - auc: 0.9722 - loss: 0.1973
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s
25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 943ms/step - accuracy: 0.9398 - auc: 0.9761 - loss: 0.1772 - val_accuracy: 0.9255 - val_auc: 0.9941 - val_loss: 0.1600 - learning_rate: 1.0000e-05
# Epoch 19/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 937ms/step - accuracy: 0.9387 - auc: 0.9732 - loss: 0.1803 - val_accuracy: 0.8997 - val_auc: 0.9937 - val_loss: 0.1865 - learning_rate: 1.0000e-05
# Epoch 20/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 940ms/step - accuracy: 0.9405 - auc: 0.9721 - loss: 0.1945 - val_accuracy: 0.9417 - val_auc: 0.9945 - val_loss: 0.1383 - learning_rate: 1.0000e-05
# Epoch 21/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 942ms/step - accuracy: 0.9350 - auc: 0.9725 - loss: 0.1879 - val_accuracy: 0.9331 - val_auc: 0.9941 - val_loss: 0.1484 - learning_rate: 1.0000e-05
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Test Loss: 0.4124
# Test Accuracy: 0.8686
# AUC: 0.9459
#
# === SEMILLA 1 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.6952 - auc: 0.6234 - loss: 2.2776 - val_accuracy: 0.7421 - val_auc: 0.8411 - val_loss: 0.7376 - learning_rate: 5.0000e-04
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 943ms/step - accuracy: 0.8160 - auc: 0.9110 - loss: 0.3234 - val_accuracy: 0.7421 - val_auc: 0.5131 - val_loss: 1.2059 - learning_rate: 5.0000e-04
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.8907 - auc: 0.9466 - loss: 0.2460
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 61s 929ms/step - accuracy: 0.8906 - auc: 0.9466 - loss: 0.2462 - val_accuracy: 0.7421 - val_auc: 0.5509 - val_loss: 1.3574 - learning_rate: 5.0000e-04
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 932ms/step - accuracy: 0.8938 - auc: 0.9501 - loss: 0.2499 - val_accuracy: 0.7421 - val_auc: 0.4870 - val_loss: 1.5552 - learning_rate: 1.5000e-04
# Epoch 5/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.9089 - auc: 0.9610 - loss: 0.2229
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 61s 930ms/step - accuracy: 0.9089 - auc: 0.9610 - loss: 0.2228 - val_accuracy: 0.7421 - val_auc: 0.7457 - val_loss: 1.2719 - learning_rate: 1.5000e-04
# Epoch 6/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 932ms/step - accuracy: 0.9214 - auc: 0.9631 - loss: 0.2308 - val_accuracy: 0.7526 - val_auc: 0.9169 - val_loss: 0.7478 - learning_rate: 4.5000e-05
# Epoch 7/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 932ms/step - accuracy: 0.9235 - auc: 0.9672 - loss: 0.2005 - val_accuracy: 0.8902 - val_auc: 0.9693 - val_loss: 0.3057 - learning_rate: 4.5000e-05
# Epoch 8/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 952ms/step - accuracy: 0.9237 - auc: 0.9666 - loss: 0.2019 - val_accuracy: 0.9599 - val_auc: 0.9823 - val_loss: 0.1576 - learning_rate: 4.5000e-05
# Epoch 9/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 949ms/step - accuracy: 0.9242 - auc: 0.9685 - loss: 0.1941 - val_accuracy: 0.9532 - val_auc: 0.9899 - val_loss: 0.1339 - learning_rate: 4.5000e-05
# Epoch 10/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s
25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 934ms/step - accuracy: 0.9375 - auc: 0.9742 - loss: 0.1781 - val_accuracy: 0.9045 - val_auc: 0.9904 - val_loss: 0.1909 - learning_rate: 1.0000e-05
# Epoch 24/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 931ms/step - accuracy: 0.9343 - auc: 0.9696 - loss: 0.1950 - val_accuracy: 0.9140 - val_auc: 0.9905 - val_loss: 0.1758 - learning_rate: 1.0000e-05
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 946ms/step - accuracy: 0.9374 - auc: 0.9745 - loss: 0.1781 - val_accuracy: 0.9121 - val_auc: 0.9906 - val_loss: 0.1766 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 25.
# Test Loss: 0.3261
# Test Accuracy: 0.8830
# AUC: 0.9476
#
# === SEMILLA 2 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.6690 - auc: 0.5908 - loss: 3.3893 - val_accuracy: 0.7421 - val_auc: 0.9318 - val_loss: 0.7158 - learning_rate: 5.0000e-04
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 944ms/step - accuracy: 0.7304 - auc: 0.8588 - loss: 0.4032 - val_accuracy: 0.7421 - val_auc: 0.7649 - val_loss: 1.3297 - learning_rate: 5.0000e-04
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - accuracy: 0.8270 - auc: 0.8820 - loss: 0.3555
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 947ms/step - accuracy: 0.8270 - auc: 0.8820 - loss: 0.3553 - val_accuracy: 0.7421 - val_auc: 0.5000 - val_loss: 1.7631 - learning_rate: 5.0000e-04
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 941ms/step - accuracy: 0.8447 - auc: 0.8963 - loss: 0.3279 - val_accuracy: 0.7421 - val_auc: 0.5000 - val_loss: 2.0078 - learning_rate: 1.5000e-04
# Epoch 5/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 808ms/step - accuracy: 0.8585 - auc: 0.9045 - loss: 0.3253
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 939ms/step - accuracy: 0.8584 - auc: 0.9044 - loss: 0.3251 - val_accuracy: 0.7421 - val_auc: 0.5000 - val_loss: 2.0745 - learning_rate: 1.5000e-04
# Epoch 6/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 941ms/step - accuracy: 0.8580 - auc: 0.9086 - loss: 0.3111 - val_accuracy: 0.7421 - val_auc: 0.7025 - val_loss: 1.4740 - learning_rate: 4.5000e-05
# Epoch 7/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 808ms/step - accuracy: 0.8565 - auc: 0.9033 - loss: 0.3179
# Epoch 7: ReduceLROnPlateau reducing learning rate to 1.3500000204658135e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 938ms/step - accuracy: 0.8565 - auc: 0.9034 - loss: 0.3178 - val_accuracy: 0.7421 - val_auc: 0.9290 - val_loss: 0.9421 - learning_rate: 4.5000e-05
# Epoch 8/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 941ms/step - accuracy: 0.8478 - auc: 0.8962 - loss: 0.3276 - val_accuracy: 0.7660 - val_auc: 0.9692 - val_loss: 0.5573 - learning_rate: 1.3500e-05
# Epoch 9/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 944ms/step - accuracy: 0.8436 - auc: 0.8946 - loss: 0.3273 - val_accuracy: 0.9198 - val_auc: 0.9875 - val_loss: 0.2516 - learning_rate: 1.3500e-05
# Epoch 10/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 938ms/step - accuracy: 0.8473 - auc: 0.8964 - loss: 0.3212 - val_accuracy: 0.9618 - val_auc: 0.9838 - val_loss: 0.2319 - learning_rate: 1.3500e-05
# Epoch 11/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 809ms/step - accuracy: 0.8544 - auc: 0.9044 - loss: 0.3125
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 937ms/step - accuracy: 0.8544 - auc: 0.9044 - loss: 0.3124 - val_accuracy: 0.9628 - val_auc: 0.9797 - val_loss: 0.2355 - learning_rate: 1.3500e-05
# Epoch 12/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 61s 923ms/step - accuracy: 0.8552 - auc: 0.9040 - loss: 0.3105 - val_accuracy: 0.9379 - val_auc: 0.9621 - val_loss: 0.2678 - learning_rate: 1.0000e-05
# Epoch 13/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 935ms/step - accuracy: 0.8489 - auc: 0.9009 - loss: 0.3169 - val_accuracy: 0.9398 - val_auc: 0.9637 - val_loss: 0.2585 - learning_rate: 1.0000e-05
# Epoch 14/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 936ms/step - accuracy: 0.8708 - auc: 0.9102 - loss: 0.3176 - val_accuracy: 0.9379 - val_auc: 0.9589 - val_loss: 0.2717 - learning_rate: 1.0000e-05
# Epoch 15/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 942ms/step - accuracy: 0.8521 - auc: 0.9027 - loss: 0.3152 - val_accuracy: 0.9064 - val_auc: 0.9406 - val_loss: 0.3017 - learning_rate: 1.0000e-05
# Epoch 16/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8480 - auc: 0.8983 - loss: 0.3212 - val_accuracy: 0.9131 - val_auc: 0.9419 - val_loss: 0.2953 - learning_rate: 1.0000e-05
# Epoch 17/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 948ms/step - accuracy: 0.8539 - auc: 0.9032 - loss: 0.3107 - val_accuracy: 0.9112 - val_auc: 0.9425 - val_loss: 0.2988 - learning_rate: 1.0000e-05
# Epoch 18/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 954ms/step - accuracy: 0.8644 - auc: 0.9110 - loss: 0.3050 - val_accuracy: 0.9064 - val_auc: 0.9394 - val_loss: 0.3027 - learning_rate: 1.0000e-05
# Epoch 19/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 948ms/step - accuracy: 0.8632 - auc: 0.9103 - loss: 0.3080 - val_accuracy: 0.9131 - val_auc: 0.9412 - val_loss: 0.2953 - learning_rate: 1.0000e-05
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Test Loss: 0.9097
# Test Accuracy: 0.6667
# AUC: 0.9229
#
# === SEMILLA 3 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.7520 - auc: 0.7255 - loss: 1.8424 - val_accuracy: 0.7421 - val_auc: 0.9188 - val_loss: 0.8176 - learning_rate: 5.0000e-04
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 939ms/step - accuracy: 0.8959 - auc: 0.9533 - loss: 0.2409 - val_accuracy: 0.7421 - val_auc: 0.8414 - val_loss: 1.0262 - learning_rate: 5.0000e-04
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 848ms/step - accuracy: 0.9106 - auc: 0.9634 - loss: 0.2154
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 974ms/step - accuracy: 0.9106 - auc: 0.9633 - loss: 0.2155 - val_accuracy: 0.7421 - val_auc: 0.5000 - val_loss: 2.0207 - learning_rate: 5.0000e-04
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s
25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 938ms/step - accuracy: 0.9481 - auc: 0.9785 - loss: 0.1647 - val_accuracy: 0.8835 - val_auc: 0.9876 - val_loss: 0.2620 - learning_rate: 1.0000e-05
# Epoch 18/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 949ms/step - accuracy: 0.9411 - auc: 0.9819 - loss: 0.1519 - val_accuracy: 0.8921 - val_auc: 0.9880 - val_loss: 0.2490 - learning_rate: 1.0000e-05
# Epoch 19/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 951ms/step - accuracy: 0.9489 - auc: 0.9797 - loss: 0.1598 - val_accuracy: 0.9303 - val_auc: 0.9890 - val_loss: 0.1765 - learning_rate: 1.0000e-05
# Epoch 20/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 953ms/step - accuracy: 0.9402 - auc: 0.9825 - loss: 0.1459 - val_accuracy: 0.9026 - val_auc: 0.9877 - val_loss: 0.2305 - learning_rate: 1.0000e-05
# Epoch 21/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 960ms/step - accuracy: 0.9484 - auc: 0.9833 - loss: 0.1418 - val_accuracy: 0.9093 - val_auc: 0.9880 - val_loss: 0.2108 - learning_rate: 1.0000e-05
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
# Test Loss: 0.3809
# Test Accuracy: 0.8734
# AUC: 0.9421
#
# === SEMILLA 4 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.6674 - auc: 0.5917 - loss: 2.4989 - val_accuracy: 0.7421 - val_auc: 0.9623 - val_loss: 0.5777 - learning_rate: 5.0000e-04
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 945ms/step - accuracy: 0.7681 - auc: 0.8694 - loss: 0.3658 - val_accuracy: 0.7421 - val_auc: 0.7377 - val_loss: 1.2074 - learning_rate: 5.0000e-04
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 811ms/step - accuracy: 0.8119 - auc: 0.9115 - loss: 0.3244
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 937ms/step - accuracy: 0.8122 - auc: 0.9115 - loss: 0.3243 - val_accuracy: 0.7421 - val_auc: 0.5000 - val_loss: 2.0129 - learning_rate: 5.0000e-04
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 936ms/step - accuracy: 0.8503 - auc: 0.9226 - loss: 0.2979 - val_accuracy: 0.7421 - val_auc: 0.5000 - val_loss: 2.1217 - learning_rate: 1.5000e-04
# Epoch 5/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 808ms/step - accuracy: 0.8745 - auc: 0.9358 - loss: 0.2785
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 933ms/step - accuracy: 0.8747 - auc: 0.9358 - loss: 0.2783 - val_accuracy: 0.7421 - val_auc: 0.5308 - val_loss: 1.6596 - learning_rate: 1.5000e-04
# Epoch 6/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 942ms/step - accuracy: 0.8854 - auc: 0.9427 - loss: 0.2633 - val_accuracy: 0.7421 - val_auc: 0.8654 - val_loss: 1.2043 - learning_rate: 4.5000e-05
# Epoch 7/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - accuracy: 0.8814 - auc: 0.9421 - loss: 0.2592
# Epoch 7: ReduceLROnPlateau reducing learning rate to 1.3500000204658135e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s
25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 937ms/step - accuracy: 0.8976 - auc: 0.9499 - loss: 0.2430 - val_accuracy: 0.9427 - val_auc: 0.9888 - val_loss: 0.1508 - learning_rate: 1.0000e-05
# Epoch 23/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 933ms/step - accuracy: 0.9007 - auc: 0.9513 - loss: 0.2340 - val_accuracy: 0.9436 - val_auc: 0.9887 - val_loss: 0.1562 - learning_rate: 1.0000e-05
# Epoch 24/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 932ms/step - accuracy: 0.8845 - auc: 0.9416 - loss: 0.2488 - val_accuracy: 0.9436 - val_auc: 0.9891 - val_loss: 0.1500 - learning_rate: 1.0000e-05
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 947ms/step - accuracy: 0.8936 - auc: 0.9502 - loss: 0.2372 - val_accuracy: 0.9456 - val_auc: 0.9893 - val_loss: 0.1473 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 25.
# Test Loss: 0.4071
# Test Accuracy: 0.8622
# AUC: 0.9425

# %% [markdown]
# #### Estas métricas nos permiten evaluar si el modelo está aprendiendo correctamente o si está cayendo en problemas como el sobreajuste.
# * **Accuracy (entrenamiento):** Mide el porcentaje de aciertos del modelo sobre los datos de entrenamiento.
# * **Accuracy (validación):** Refleja la precisión sobre datos nunca vistos durante el entrenamiento.
# * **Loss (entrenamiento):** Es la función de pérdida que el modelo intenta minimizar.
# * **Loss (validación):** Igual que la de entrenamiento, pero en validación.
# * **AUC:** Esta métrica mide la capacidad del modelo para diferenciar entre clases. Valores cercanos a 1.0 indican una excelente discriminación.
# * **Reducción de Learning Rate + Early Stopping:** Se han utilizado callbacks para detener el entrenamiento (EarlyStopping) cuando la métrica de validación deja de mejorar después de un número determinado de épocas (patience). Y para reducir la tasa de aprendizaje (ReduceLROnPlateau) cuando la métrica monitorizada (val_auc) se estanca. Esto ayuda a que el optimizador realice ajustes más finos, mejorando la convergencia sin provocar grandes oscilaciones.

# %% [markdown]
# ## **Análisis Después del Entrenamiento**

# %%
# Elegimos semilla
history = histories[0] 

# Accuracy
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Precisión (Accuracy)')
plt.xlabel('Época')
plt.ylabel('Precisión')
plt.legend()
plt.grid(True)
plt.show()

# Loss
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Pérdida (Loss)')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# * **Precisión (Accuracy)**
#     * En las primeras épocas, la precisión en validación permanece estancada mientras el modelo empieza a aprender patrones básicos.
#     * Posteriormente, la curva de validación se eleva bruscamente, lo que indica que el modelo comienza a generalizar y acertar en imágenes no vistas.
#     * Es curioso cuando la precisión en validación supera a la de entrenamiento: el conjunto de validación es más "fácil" porque no contiene Data Augmentation, a diferencia del entrenamiento que sí incluye aumentos (rotaciones, desplazamientos, etc.), haciendo las imágenes más difíciles de aprender.
#
# * **Pérdida (Loss)**
#     * La pérdida disminuye de forma consistente tanto en entrenamiento como en validación, lo cual es una buena señal.
#     * Indica que el modelo no solo acierta más, sino que comete errores menos graves (predice con mayor confianza).

# %% [markdown]
# ## **Evaluación del Rendimiento Custom**

# %%
def evaluar_modelo(modelo, test_generator, nombre_modelo="Modelo"):
    test_generator.shuffle = False
    test_generator.reset()
    
    y_pred_probs = modelo.predict(test_generator)
    y_pred = (y_pred_probs > 0.5).astype(int).flatten()
    y_true = test_generator.classes

    # Matriz de confusión
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",xticklabels=test_generator.class_indices.keys(),yticklabels=test_generator.class_indices.keys())
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title(f"Matriz de Confusión - {nombre_modelo}")
    plt.show()

    # Métricas de Clasificación
    print(f"\nMétricas de Clasificación - {nombre_modelo}")
    print(classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys()))

    # AUC-ROC y Especificidad
    auc = roc_auc_score(y_true, y_pred_probs)
    print(f"AUC-ROC: {auc:.4f}")
    
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    specificity = tn / (tn + fp)
    print(f"Especificidad: {specificity:.4f}")

    return y_true, y_pred, y_pred_probs

# %%
# Elegimos la semilla para ver las métricas de esa ejecución
y_true, y_pred, y_pred_probs = evaluar_modelo(models[0], test_generator, nombre_modelo="CNN Custom")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 409ms/step
# Métricas de Clasificación - CNN Custom
#               precision    recall  f1-score   support
#
#       NORMAL       0.94      0.70      0.80       234
#    PNEUMONIA       0.84      0.97      0.90       390
#
#     accuracy                           0.87       624
#    macro avg       0.89      0.83      0.85       624
# weighted avg       0.88      0.87      0.86       624
#
# AUC-ROC: 0.9524
# Especificidad: 0.6966

# %% [markdown]
# #### **Matriz de Confusión:**
# #### Nos permite observar el rendimiento del modelo clasificando correctamente las imágenes en ambas clases: NORMAL y PNEUMONIA.
# * #### Clasifica correctamente la mayoría de los casos de **PNEUMONIA**: 379 de 390
# * #### En la clase **NORMAL** clasifica correctamente: 163 de 234. Hay mas errores, lo que reduce la **especificidad**.
# #### Esto es común en datasets médicos, donde suele ser más grave fallar en un positivo (falso negativo) que en un falso positivo.
#
# #### **Métricas de Clasificación:**
# #### **1. Precisión**
# * #### NORMAL ->  0.94. El 94% de las veces que el modelo predice que es normal, acierta.
# * #### PNEUMONIA ->  0.84. El 84% de las veces que predice neumonía, acierta.
#
# #### **2. Recall (Sensibilidad)**
# * #### NORMAL -> 0.70. Tiene más dificultades detectando correctamente imágenes sin neumonía (más falsos positivos).
# * #### PNEUMONIA ->  0.97. El modelo detecta correctamente el 97% de los casos enfermos (muy relevante en diagnóstico médico).
#
# #### **3. F1-Score**
# * #### Buen equilibrio entre precisión y recall, especialmente alto en la clase neumonía (0.90), lo que refuerza su utilidad como modelo de ayuda diagnóstica.
#
# #### **4. Accuracy** -> 0.87
# * #### Precisión global del modelo. Es un buen valor, pero puede ser engañoso si el dataset está desbalanceado.
#
# #### **AUC-ROC (0.9524):**
# * #### Indica excelente capacidad del modelo para distinguir entre ambas clases. Cuanto más cerca de 1, mejor.
#
# #### **Especificidad (0.6966):**
# * #### Mide la capacidad del modelo para identificar correctamente los casos normales. Es sensiblemente inferior al recall de neumonía, lo que sugiere un sesgo del modelo hacia la detección de neumonía. Esto podría estar relacionado con un desbalanceo leve o con un patrón más claro en los casos positivos que en los negativos.

# %% [markdown]
# ## **Conjunto Test: Ejemplos clasificados correctamente**

# %% [markdown]
# #### En este y el siguiente apartado, analizamos visualmente las imágenes bien clasificadas, y especialmente las mal clasificadas (falsos positivos y falsos negativos), para entender si el error es comprensible incluso para un humano (ruido, baja calidad, mal etiquetado, etc.).

# %%
test_generator.reset()

x_imgs = []
for i in range(len(test_generator)):
    batch_imgs, _ = test_generator[i]
    x_imgs.extend(batch_imgs)
x_imgs = np.array(x_imgs)

correct = [i for i in range(len(y_pred)) if y_pred[i] == y_true[i]]

plt.figure(figsize=(12, 6))
for i, c in enumerate(correct[:6]):
    plt.subplot(2, 3, i + 1)
    plt.imshow(x_imgs[c], cmap='gray')
    plt.title(f"[✓] Pred: {y_pred[c]} / Real: {y_true[c]}")
    plt.xticks([]), plt.yticks([])
plt.suptitle("Ejemplos de Clasificación Correcta", fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Conjunto Test: Ejemplos clasificados incorrectamente**

# %%
test_generator.reset()

x_imgs = []
for i in range(len(test_generator)):
    batch_imgs, _ = test_generator[i]
    x_imgs.extend(batch_imgs)
x_imgs = np.array(x_imgs)

incorrect = [i for i in range(len(y_pred)) if y_pred[i] != y_true[i]]

plt.figure(figsize=(12, 6))
for i, c in enumerate(incorrect[:6]):
    plt.subplot(2, 3, i + 1)
    plt.imshow(x_imgs[c], cmap='gray')
    plt.title(f"[x] Pred: {y_pred[c]} / Real: {y_true[c]}")
    plt.xticks([]), plt.yticks([])
plt.suptitle("Ejemplos de Clasificación Incorrecta", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Transfer Learning**

# %%
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras import backend as K

# %% [markdown]
# #### En este segundo enfoque, denominado Transfer Learning (aprendizaje por transferencia), consiste en utilizar un modelo preentrenado como extractor de características. Se seleccionarán DenseNet121 y ResNet50, ambos disponibles en el paquete Keras.
#
# #### Estos modelos ya se entrenaron en otro conjunto de datos (ImageNet). Lo que se hará aquí es establecer **include_top=False**, es decir, quitamos el clasificador final del modelo original de ImageNet, responsable de asignar las clases para el conjunto de datos, y nos quedamos solo con las capas convolucionales que extraen las características.
#
# #### Más adelante que aplicará fine-tuning, para lo cual es necesario descongelar los pesos de algunas capas convolucionales ya entrenadas. Estableceremos **layer.trainable = True**
#
# #### Finalmente añadir que existen versiones de DenseNet y ResNet con una precisión esperada algo mejor, tales como: DenseNet201 o ResNet152 pero con una velocidad algo mas lenta, muchos mas millones de parámetros, etc. El motivo de descartarlas ha sido principalmente por la velocidad y tiempo, al necesitar GPU muy potentes.

# %% [markdown]
# ## **Entrenamiento del Modelo 2: DenseNet121**

# %% [markdown]
# ## **Feature Extraction D**

# %% [markdown]
# ### **Modelo base**
# #### Hemos cargado el modelo base DenseNet121 con pesos preentrenados en ImageNet, excluyendo su capa de clasificación (include_top=False). Todas las capas se han congelado (trainable=False), por lo que en esta etapa ningún peso se actualizará durante el entrenamiento.
#
# ### **Top model**
# #### Hemos añadido nuestro propio clasificador al final del modelo base, compuesto por capas densas adaptadas al problema binario (sigmoid). Solo los pesos de esta nueva "cabeza" se entrenan, mientras que las capas convolucionales preentrenadas permanecen congeladas.
#
# #### Esto se conoce como feature extraction, ya que reutilizamos las características previamente aprendidas por el modelo (en ImageNet) y solo entrenamos la parte final con nuestro conjunto de datos.

# %%
def build_densenet_model(img_size=150):
    # Modelo base
    base_model_densenet = DenseNet121(weights='imagenet',include_top=False,input_shape=(img_size, img_size, 3))
    base_model_densenet.trainable = False

    # Top model
    x = base_model_densenet.output
    x = GlobalAveragePooling2D()(x)             
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    output = Dense(1, activation='sigmoid')(x)

    model_densenet = Model(inputs=base_model_densenet.input, outputs=output)
    model_densenet.compile(
        loss='binary_crossentropy',
        optimizer='adam',
        metrics=['accuracy', AUC(name='auc')]
    )
    return model_densenet

model_densenet = build_densenet_model()
model_densenet.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 150, 150, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ zero_padding2d_2          │ (None, 156, 156, 3)    │              0 │ input_layer_1[0][0]    │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_conv (Conv2D)       │ (None, 75, 75, 64)     │          9,408 │ zero_padding2d_2[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_bn                  │ (None, 75, 75, 64)     │            256 │ conv1_conv[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_relu (Activation)   │ (None, 75, 75, 64)     │              0 │ conv1_bn[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ zero_padding2d_3          │ (None, 77, 77, 64)     │              0 │ conv1_relu[0][0]       │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool1 (MaxPooling2D)      │ (None, 38, 38, 64)     │              0 │ zero_padding2d_3[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_0_bn         │ (None, 38, 38, 64)     │            256 │ pool1[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_0_relu       │ (None, 38, 38, 64)     │              0 │ conv2_block1_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_conv       │ (None, 38, 38, 128)    │          8,192 │ conv2_block1_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_bn         │ (None, 38, 38, 128)    │            512 │ conv2_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_relu       │ (None, 38, 38, 128)    │              0 │ conv2_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_2_conv       │ (None, 38, 38, 32)     │         36,864 │ conv2_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_concat       │ (None, 38, 38, 96)     │              0 │ pool1[0][0],           │
# │ (Concatenate)             │                        │                │ conv2_block1_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_0_bn         │ (None, 38, 38, 96)     │            384 │ conv2_block1_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_0_relu       │ (None, 38, 38, 96)     │              0 │ conv2_block2_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_conv       │ (None, 38, 38, 128)    │         12,288 │ conv2_block2_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_bn         │ (None, 38, 38, 128)    │            512 │ conv2_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_relu       │ (None, 38, 38, 128)    │              0 │ conv2_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_2_conv       │ (None, 38, 38, 32)     │         36,864 │ conv2_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_concat       │ (None, 38, 38, 128)    │              0 │ conv2_block1_concat[0… │
# │ (Concatenate)             │                        │                │ conv2_block2_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_0_bn         │ (None, 38, 38, 128)    │            512 │ conv2_block2_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_0_relu       │ (None, 38, 38, 128)    │              0 │ conv2_block3_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_conv       │ (None, 38, 38, 128)    │         16,384 │ conv2_block3_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_bn         │ (None, 38, 38, 128)    │            512 │ conv2_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_relu       │ (None, 38, 38, 128)    │              0 │ conv2_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_2_conv       │ (None, 38, 38, 32)     │         36,864 │ conv2_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_concat       │ (None, 38, 38, 160)    │              0 │ conv2_block2_concat[0… │
# │ (Concatenate)             │                        │                │ conv2_block3_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_0_bn         │ (None, 38, 38, 160)    │            640 │ conv2_block3_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_0_relu       │ (None, 38, 38, 160)    │              0 │ conv2_block4_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_1_conv       │ (None, 38, 38, 128)    │         20,480 │ conv2_block4_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_1_bn         │ (None, 38, 38, 128)    │            512 │ conv2_block4_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_1_relu       │ (None, 38, 38, 128)    │              0 │ conv2_block4_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_2_conv       │ (None, 38, 38, 32)     │         36,864 │ conv2_block4_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_concat       │ (None, 38, 38, 192)    │              0 │ conv2_block3_concat[0… │
# │ (Concatenate)             │                        │                │ conv2_block4_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_0_bn         │ (None, 38, 38, 192)    │            768 │ conv2_block4_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_0_relu       │ (None, 38, 38, 192)    │              0 │ conv2_block5_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_1_conv       │ (None, 38, 38, 128)    │         24,576 │ conv2_block5_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_1_bn         │ (None, 38, 38, 128)    │            512 │ conv2_block5_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_1_relu       │ (None, 38, 38, 128)    │              0 │ conv2_block5_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_2_conv       │ (None, 38, 38, 32)     │         36,864 │ conv2_block5_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_concat       │ (None, 38, 38, 224)    │              0 │ conv2_block4_concat[0… │
# │ (Concatenate)             │                        │                │ conv2_block5_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_0_bn         │ (None, 38, 38, 224)    │            896 │ conv2_block5_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_0_relu       │ (None, 38, 38, 224)    │              0 │ conv2_block6_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_1_conv       │ (None, 38, 38, 128)    │         28,672 │ conv2_block6_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_1_bn         │ (None, 38, 38, 128)    │            512 │ conv2_block6_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_1_relu       │ (None, 38, 38, 128)    │              0 │ conv2_block6_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_2_conv       │ (None, 38, 38, 32)     │         36,864 │ conv2_block6_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_concat       │ (None, 38, 38, 256)    │              0 │ conv2_block5_concat[0… │
# │ (Concatenate)             │                        │                │ conv2_block6_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool2_bn                  │ (None, 38, 38, 256)    │          1,024 │ conv2_block6_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool2_relu (Activation)   │ (None, 38, 38, 256)    │              0 │ pool2_bn[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool2_conv (Conv2D)       │ (None, 38, 38, 128)    │         32,768 │ pool2_relu[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool2_pool                │ (None, 19, 19, 128)    │              0 │ pool2_conv[0][0]       │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_0_bn         │ (None, 19, 19, 128)    │            512 │ pool2_pool[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_0_relu       │ (None, 19, 19, 128)    │              0 │ conv3_block1_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_conv       │ (None, 19, 19, 128)    │         16,384 │ conv3_block1_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_bn         │ (None, 19, 19, 128)    │            512 │ conv3_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_relu       │ (None, 19, 19, 128)    │              0 │ conv3_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_2_conv       │ (None, 19, 19, 32)     │         36,864 │ conv3_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_concat       │ (None, 19, 19, 160)    │              0 │ pool2_pool[0][0],      │
# │ (Concatenate)             │                        │                │ conv3_block1_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_0_bn         │ (None, 19, 19, 160)    │            640 │ conv3_block1_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_0_relu       │ (None, 19, 19, 160)    │              0 │ conv3_block2_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_conv       │ (None, 19, 19, 128)    │         20,480 │ conv3_block2_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_bn         │ (None, 19, 19, 128)    │            512 │ conv3_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_relu       │ (None, 19, 19, 128)    │              0 │ conv3_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_2_conv       │ (None, 19, 19, 32)     │         36,864 │ conv3_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_concat       │ (None, 19, 19, 192)    │              0 │ conv3_block1_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block2_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_0_bn         │ (None, 19, 19, 192)    │            768 │ conv3_block2_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_0_relu       │ (None, 19, 19, 192)    │              0 │ conv3_block3_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_conv       │ (None, 19, 19, 128)    │         24,576 │ conv3_block3_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_bn         │ (None, 19, 19, 128)    │            512 │ conv3_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_relu       │ (None, 19, 19, 128)    │              0 │ conv3_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_2_conv       │ (None, 19, 19, 32)     │         36,864 │ conv3_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_concat       │ (None, 19, 19, 224)    │              0 │ conv3_block2_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block3_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_0_bn         │ (None, 19, 19, 224)    │            896 │ conv3_block3_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_0_relu       │ (None, 19, 19, 224)    │              0 │ conv3_block4_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_conv       │ (None, 19, 19, 128)    │         28,672 │ conv3_block4_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_bn         │ (None, 19, 19, 128)    │            512 │ conv3_block4_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_relu       │ (None, 19, 19, 128)    │              0 │ conv3_block4_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_2_conv       │ (None, 19, 19, 32)     │         36,864 │ conv3_block4_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_concat       │ (None, 19, 19, 256)    │              0 │ conv3_block3_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block4_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_0_bn         │ (None, 19, 19, 256)    │          1,024 │ conv3_block4_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_0_relu       │ (None, 19, 19, 256)    │              0 │ conv3_block5_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_1_conv       │ (None, 19, 19, 128)    │         32,768 │ conv3_block5_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_1_bn         │ (None, 19, 19, 128)    │            512 │ conv3_block5_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_1_relu       │ (None, 19, 19, 128)    │              0 │ conv3_block5_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_2_conv       │ (None, 19, 19, 32)     │         36,864 │ conv3_block5_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_concat       │ (None, 19, 19, 288)    │              0 │ conv3_block4_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block5_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_0_bn         │ (None, 19, 19, 288)    │          1,152 │ conv3_block5_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_0_relu       │ (None, 19, 19, 288)    │              0 │ conv3_block6_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_1_conv       │ (None, 19, 19, 128)    │         36,864 │ conv3_block6_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_1_bn         │ (None, 19, 19, 128)    │            512 │ conv3_block6_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_1_relu       │ (None, 19, 19, 128)    │              0 │ conv3_block6_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_2_conv       │ (None, 19, 19, 32)     │         36,864 │ conv3_block6_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_concat       │ (None, 19, 19, 320)    │              0 │ conv3_block5_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block6_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_0_bn         │ (None, 19, 19, 320)    │          1,280 │ conv3_block6_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_0_relu       │ (None, 19, 19, 320)    │              0 │ conv3_block7_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_1_conv       │ (None, 19, 19, 128)    │         40,960 │ conv3_block7_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_1_bn         │ (None, 19, 19, 128)    │            512 │ conv3_block7_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_1_relu       │ (None, 19, 19, 128)    │              0 │ conv3_block7_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_2_conv       │ (None, 19, 19, 32)     │         36,864 │ conv3_block7_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_concat       │ (None, 19, 19, 352)    │              0 │ conv3_block6_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block7_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block8_0_bn         │ (None, 19, 19, 352)    │          1,408 │ conv3_block7_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block8_0_relu       │ (None, 19, 19, 352)    │              0 │ conv3_block8_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block8_1_conv       │ (None, 19, 19, 128)    │         45,056 │ conv3_block8_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block8_1_bn         │ (None, 19, 19, 128)    │            512 │ conv3_block8_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block8_1_relu       │ (None, 19, 19, 128)    │              0 │ conv3_block8_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block8_2_conv       │ (None, 19, 19, 32)     │         36,864 │ conv3_block8_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block8_concat       │ (None, 19, 19, 384)    │              0 │ conv3_block7_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block8_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block9_0_bn         │ (None, 19, 19, 384)    │          1,536 │ conv3_block8_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block9_0_relu       │ (None, 19, 19, 384)    │              0 │ conv3_block9_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block9_1_conv       │ (None, 19, 19, 128)    │         49,152 │ conv3_block9_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block9_1_bn         │ (None, 19, 19, 128)    │            512 │ conv3_block9_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block9_1_relu       │ (None, 19, 19, 128)    │              0 │ conv3_block9_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block9_2_conv       │ (None, 19, 19, 32)     │         36,864 │ conv3_block9_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block9_concat       │ (None, 19, 19, 416)    │              0 │ conv3_block8_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block9_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block10_0_bn        │ (None, 19, 19, 416)    │          1,664 │ conv3_block9_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block10_0_relu      │ (None, 19, 19, 416)    │              0 │ conv3_block10_0_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block10_1_conv      │ (None, 19, 19, 128)    │         53,248 │ conv3_block10_0_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block10_1_bn        │ (None, 19, 19, 128)    │            512 │ conv3_block10_1_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block10_1_relu      │ (None, 19, 19, 128)    │              0 │ conv3_block10_1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block10_2_conv      │ (None, 19, 19, 32)     │         36,864 │ conv3_block10_1_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block10_concat      │ (None, 19, 19, 448)    │              0 │ conv3_block9_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block10_2_conv[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block11_0_bn        │ (None, 19, 19, 448)    │          1,792 │ conv3_block10_concat[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block11_0_relu      │ (None, 19, 19, 448)    │              0 │ conv3_block11_0_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block11_1_conv      │ (None, 19, 19, 128)    │         57,344 │ conv3_block11_0_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block11_1_bn        │ (None, 19, 19, 128)    │            512 │ conv3_block11_1_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block11_1_relu      │ (None, 19, 19, 128)    │              0 │ conv3_block11_1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block11_2_conv      │ (None, 19, 19, 32)     │         36,864 │ conv3_block11_1_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block11_concat      │ (None, 19, 19, 480)    │              0 │ conv3_block10_concat[… │
# │ (Concatenate)             │                        │                │ conv3_block11_2_conv[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block12_0_bn        │ (None, 19, 19, 480)    │          1,920 │ conv3_block11_concat[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block12_0_relu      │ (None, 19, 19, 480)    │              0 │ conv3_block12_0_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block12_1_conv      │ (None, 19, 19, 128)    │         61,440 │ conv3_block12_0_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block12_1_bn        │ (None, 19, 19, 128)    │            512 │ conv3_block12_1_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block12_1_relu      │ (None, 19, 19, 128)    │              0 │ conv3_block12_1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block12_2_conv      │ (None, 19, 19, 32)     │         36,864 │ conv3_block12_1_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_
… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block16_0_relu      │ (None, 4, 4, 992)      │              0 │ conv5_block16_0_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block16_1_conv      │ (None, 4, 4, 128)      │        126,976 │ conv5_block16_0_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block16_1_bn        │ (None, 4, 4, 128)      │            512 │ conv5_block16_1_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block16_1_relu      │ (None, 4, 4, 128)      │              0 │ conv5_block16_1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block16_2_conv      │ (None, 4, 4, 32)       │         36,864 │ conv5_block16_1_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block16_concat      │ (None, 4, 4, 1024)     │              0 │ conv5_block15_concat[… │
# │ (Concatenate)             │                        │                │ conv5_block16_2_conv[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn (BatchNormalization)   │ (None, 4, 4, 1024)     │          4,096 │ conv5_block16_concat[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ relu (Activation)         │ (None, 4, 4, 1024)     │              0 │ bn[0][0]               │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 1024)           │              0 │ relu[0][0]             │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 1024)           │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 1024)           │          4,096 │ dropout_2[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 128)            │        131,200 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 128)            │              0 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 1)              │            129 │ dropout_3[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,172,929 (27.36 MB)
#  Trainable params: 133,377 (521.00 KB)
#  Non-trainable params: 7,039,552 (26.85 MB)

# %% [markdown]
# **Resumen arquitectura:**
#
# Total params: 7,172,929 (27.36 MB)
#
# Trainable params: 133,377 (521.00 KB)
#
# Non-trainable params: 7,039,552 (26.85 MB)

# %%
img_size = 150
batch_size = 64
seeds = [0, 1, 2, 3, 4]

results_densenet_list = []
histories_densenet = {}
models_densenet = {}

test_paths, test_labels = get_image_paths_labels(test_dir)
test_df = pd.DataFrame({'filename': test_paths, 'label': test_labels})

for seed in seeds:
    print(f"\n=== SEMILLA {seed} ===")

    tf.random.set_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    
    # Preparar datos
    train_df, val_df = get_dataframes(train_dir, val_dir, seed)
    train_generator, val_generator, test_generator = get_data_generators(train_df, val_df, test_df, img_size, batch_size, seed)
    
    # Ajuste de pesos
    class_weights = get_class_weights(train_df)
    
    # Crear modelo DenseNet121
    model_densenet = build_densenet_model(img_size)
    
    # Callbacks
    callbacks = get_callbacks()
    
    # Entrenamiento
    history_densenet = model_densenet.fit(
        train_generator,
        validation_data=val_generator,
        epochs=25,
        class_weight=class_weights,
        callbacks=callbacks,
    )

    histories_densenet[seed] = history_densenet
    models_densenet[seed] = model_densenet
    
    # Evaluación en test
    results_densenet = model_densenet.evaluate(test_generator, verbose=0)
    print(f"Test Loss: {results_densenet[0]:.4f}")
    print(f"Test Accuracy: {results_densenet[1]:.4f}")
    print(f"AUC: {results_densenet[2]:.4f}")
    
    # Guardar resultados
    results_densenet_list.append({
        'Seed': seed,
        'Test Loss': results_densenet[0],
        'Test Accuracy': results_densenet[1],
        'Test AUC': results_densenet[2]
    })

# Mostramos resultados
df_results_densenet = pd.DataFrame(results_densenet_list)

plt.figure(figsize=(8, 6))
sns.boxplot(data=df_results_densenet[['Test Accuracy', 'Test AUC', 'Test Loss']])
plt.title('Distribución de métricas en test (5 semillas) - DenseNet121 (FE)')
plt.grid(True)
plt.show()
# Out:
# === SEMILLA 0 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━
25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9281 - auc: 0.9764 - loss: 0.1708 - val_accuracy: 0.9561 - val_auc: 0.9896 - val_loss: 0.1373 - learning_rate: 0.0010
# Epoch 17/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 65s 986ms/step - accuracy: 0.9263 - auc: 0.9694 - loss: 0.1875 - val_accuracy: 0.9475 - val_auc: 0.9893 - val_loss: 0.1406 - learning_rate: 0.0010
# Epoch 18/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1000ms/step - accuracy: 0.9302 - auc: 0.9760 - loss: 0.1771 - val_accuracy: 0.9465 - val_auc: 0.9900 - val_loss: 0.1414 - learning_rate: 0.0010
# Epoch 19/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9224 - auc: 0.9722 - loss: 0.1805 - val_accuracy: 0.9360 - val_auc: 0.9888 - val_loss: 0.1562 - learning_rate: 0.0010
# Epoch 20/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9294 - auc: 0.9764 - loss: 0.1705
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 969ms/step - accuracy: 0.9293 - auc: 0.9763 - loss: 0.1706 - val_accuracy: 0.9341 - val_auc: 0.9888 - val_loss: 0.1594 - learning_rate: 0.0010
# Epoch 21/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 960ms/step - accuracy: 0.9337 - auc: 0.9767 - loss: 0.1672 - val_accuracy: 0.9398 - val_auc: 0.9896 - val_loss: 0.1516 - learning_rate: 3.0000e-04
# Epoch 22/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 971ms/step - accuracy: 0.9313 - auc: 0.9727 - loss: 0.1822 - val_accuracy: 0.9532 - val_auc: 0.9903 - val_loss: 0.1378 - learning_rate: 3.0000e-04
# Epoch 23/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 973ms/step - accuracy: 0.9240 - auc: 0.9707 - loss: 0.1879 - val_accuracy: 0.9484 - val_auc: 0.9905 - val_loss: 0.1411 - learning_rate: 3.0000e-04
# Epoch 24/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 972ms/step - accuracy: 0.9300 - auc: 0.9762 - loss: 0.1727 - val_accuracy: 0.9608 - val_auc: 0.9912 - val_loss: 0.1277 - learning_rate: 3.0000e-04
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 974ms/step - accuracy: 0.9326 - auc: 0.9784 - loss: 0.1649 - val_accuracy: 0.9513 - val_auc: 0.9911 - val_loss: 0.1319 - learning_rate: 3.0000e-04
# Restoring model weights from the end of the best epoch: 24.
# Test Loss: 0.2884
# Test Accuracy: 0.8846
# AUC: 0.9600
#
# === SEMILLA 1 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.8239 - auc: 0.8344 - loss: 0.4002 - val_accuracy: 0.8176 - val_auc: 0.9672 - val_loss: 0.4181 - learning_rate: 0.0010
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9148 - auc: 0.9626 - loss: 0.2147 - val_accuracy: 0.8758 - val_auc: 0.9710 - val_loss: 0.2689 - learning_rate: 0.0010
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1000ms/step - accuracy: 0.9104 - auc: 0.9644 - loss: 0.2123 - val_accuracy: 0.8883 - val_auc: 0.9765 - val_loss: 0.2358 - learning_rate: 0.0010
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 968ms/step - accuracy: 0.9079 - auc: 0.9624 - loss: 0.2200 - val_accuracy: 0.8863 - val_auc: 0.9795 - val_loss: 0.2357 - learning_rate: 0.0010
# Epoch 5/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s
25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 997ms/step - accuracy: 0.9254 - auc: 0.9743 - loss: 0.1801 - val_accuracy: 0.9255 - val_auc: 0.9853 - val_loss: 0.1786 - learning_rate: 1.0000e-05
# Epoch 20/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9273 - auc: 0.9727 - loss: 0.1828 - val_accuracy: 0.9255 - val_auc: 0.9852 - val_loss: 0.1778 - learning_rate: 1.0000e-05
# Epoch 21/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - accuracy: 0.9151 - auc: 0.9723 - loss: 0.1870 - val_accuracy: 0.9265 - val_auc: 0.9853 - val_loss: 0.1774 - learning_rate: 1.0000e-05
# Epoch 22/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9326 - auc: 0.9753 - loss: 0.1750 - val_accuracy: 0.9274 - val_auc: 0.9853 - val_loss: 0.1769 - learning_rate: 1.0000e-05
# Epoch 23/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9222 - auc: 0.9707 - loss: 0.1866 - val_accuracy: 0.9274 - val_auc: 0.9854 - val_loss: 0.1750 - learning_rate: 1.0000e-05
# Epoch 24/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9204 - auc: 0.9709 - loss: 0.1873 - val_accuracy: 0.9284 - val_auc: 0.9854 - val_loss: 0.1739 - learning_rate: 1.0000e-05
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 977ms/step - accuracy: 0.9254 - auc: 0.9710 - loss: 0.1906 - val_accuracy: 0.9284 - val_auc: 0.9854 - val_loss: 0.1758 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 24.
# Test Loss: 0.3021
# Test Accuracy: 0.8894
# AUC: 0.9481
#
# === SEMILLA 2 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - accuracy: 0.5985 - auc: 0.7892 - loss: 0.8063 - val_accuracy: 0.8510 - val_auc: 0.9672 - val_loss: 0.3547 - learning_rate: 0.0010
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 969ms/step - accuracy: 0.8946 - auc: 0.9415 - loss: 0.2678 - val_accuracy: 0.9198 - val_auc: 0.9746 - val_loss: 0.2137 - learning_rate: 0.0010
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9108 - auc: 0.9616 - loss: 0.2152 - val_accuracy: 0.9293 - val_auc: 0.9791 - val_loss: 0.1814 - learning_rate: 0.0010
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9225 - auc: 0.9677 - loss: 0.1991 - val_accuracy: 0.9274 - val_auc: 0.9802 - val_loss: 0.1848 - learning_rate: 0.0010
# Epoch 5/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 962ms/step - accuracy: 0.9088 - auc: 0.9620 - loss: 0.2165 - val_accuracy: 0.9341 - val_auc: 0.9839 - val_loss: 0.1697 - learning_rate: 0.0010
# Epoch 6/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 960ms/step - accuracy: 0.9144 - auc: 0.9600 - loss: 0.2143 - val_accuracy: 0.9236 - val_auc: 0.9838 - val_loss: 0.1856 - learning_rate: 0.0010
# Epoch 7/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 964ms/step - accuracy: 0.9180 - auc: 0.9681 - loss: 0.2002 - val_accuracy: 0.9351 - val_auc: 0.9845 - val_loss: 0.1664 - learning_rate: 0.0010
# Epoch 8/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 970ms/step - accuracy: 0.9113 - auc: 0.9656 - loss: 0.2115 - val_accuracy: 0.9322 - val_auc: 0.9845 - val_loss: 0.1694 - learning_rate: 0.0010
# Epoch 9/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s
25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 65s 983ms/step - accuracy: 0.9265 - auc: 0.9692 - loss: 0.1943 - val_accuracy: 0.9303 - val_auc: 0.9890 - val_loss: 0.1650 - learning_rate: 3.0000e-04
# Epoch 15/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 852ms/step - accuracy: 0.9210 - auc: 0.9742 - loss: 0.1783
# Epoch 15: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 65s 986ms/step - accuracy: 0.9211 - auc: 0.9742 - loss: 0.1783 - val_accuracy: 0.9351 - val_auc: 0.9890 - val_loss: 0.1578 - learning_rate: 3.0000e-04
# Epoch 16/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 961ms/step - accuracy: 0.9252 - auc: 0.9716 - loss: 0.1866 - val_accuracy: 0.9341 - val_auc: 0.9889 - val_loss: 0.1596 - learning_rate: 9.0000e-05
# Epoch 17/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 959ms/step - accuracy: 0.9277 - auc: 0.9743 - loss: 0.1750 - val_accuracy: 0.9379 - val_auc: 0.9891 - val_loss: 0.1554 - learning_rate: 9.0000e-05
# Epoch 18/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 958ms/step - accuracy: 0.9139 - auc: 0.9679 - loss: 0.2008 - val_accuracy: 0.9370 - val_auc: 0.9890 - val_loss: 0.1570 - learning_rate: 9.0000e-05
# Epoch 19/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 820ms/step - accuracy: 0.9341 - auc: 0.9790 - loss: 0.1626
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 957ms/step - accuracy: 0.9340 - auc: 0.9790 - loss: 0.1628 - val_accuracy: 0.9341 - val_auc: 0.9891 - val_loss: 0.1581 - learning_rate: 9.0000e-05
# Epoch 20/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 968ms/step - accuracy: 0.9326 - auc: 0.9750 - loss: 0.1705 - val_accuracy: 0.9379 - val_auc: 0.9890 - val_loss: 0.1562 - learning_rate: 2.7000e-05
# Epoch 21/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.9248 - auc: 0.9702 - loss: 0.1907
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9248 - auc: 0.9702 - loss: 0.1906 - val_accuracy: 0.9389 - val_auc: 0.9890 - val_loss: 0.1539 - learning_rate: 2.7000e-05
# Epoch 22/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 974ms/step - accuracy: 0.9304 - auc: 0.9737 - loss: 0.1794 - val_accuracy: 0.9389 - val_auc: 0.9890 - val_loss: 0.1553 - learning_rate: 1.0000e-05
# Epoch 23/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 961ms/step - accuracy: 0.9323 - auc: 0.9772 - loss: 0.1701 - val_accuracy: 0.9379 - val_auc: 0.9890 - val_loss: 0.1554 - learning_rate: 1.0000e-05
# Epoch 24/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 959ms/step - accuracy: 0.9333 - auc: 0.9749 - loss: 0.1725 - val_accuracy: 0.9370 - val_auc: 0.9890 - val_loss: 0.1554 - learning_rate: 1.0000e-05
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 961ms/step - accuracy: 0.9168 - auc: 0.9703 - loss: 0.1925 - val_accuracy: 0.9389 - val_auc: 0.9890 - val_loss: 0.1550 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 17.
# Test Loss: 0.2844
# Test Accuracy: 0.9006
# AUC: 0.9540

# %%
# Elegimos semilla
history_densenet = histories_densenet[4] 

# Accuracy
plt.plot(history_densenet.history['accuracy'], label='Entrenamiento')
plt.plot(history_densenet.history['val_accuracy'], label='Validación')
plt.title('Precisión (Accuracy)')
plt.xlabel('Época')
plt.ylabel('Precisión')
plt.legend()
plt.grid(True)
plt.show()

# Loss
plt.plot(history_densenet.history['loss'], label='Entrenamiento')
plt.plot(history_densenet.history['val_loss'], label='Validación')
plt.title('Pérdida (Loss)')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Fine-tuning D**

# %% [markdown]
# #### Tras realizar feature extraction, el siguiente paso es el fine-tuning.
#
# #### Descongelamos parte de las capas del modelo preentrenado para permitir que se ajusten mejor a nuestro dataset médico. De esta forma el modelo puede adaptar los patrones aprendidos en ImageNet a los patrones más específicos presentes en las radiografías del dataset.
#
# #### En este caso:
# #### - Se descongelan las capas de índice 150 en adelante (últimas 277). El modelo tiene 427 capas en total.
# #### - Se recompila el modelo con una **tasa de aprendizaje muy baja (`1e-5`)** para no sobrescribir los pesos preentrenados. Es práctica habitual en fine-tuning o incluso mas bajos. Recordemos el learning rate por defecto en Adam es 0,001.
#
# #### Este ajuste fino permite aprovechar lo mejor del aprendizaje previo.

# %%
def build_densenet_model_ft(img_size=224, learning_rate=1e-5):
    # Modelo base
    base_model_densenet_ft = DenseNet121(weights='imagenet', include_top=False, input_shape=(img_size, img_size, 3))
    base_model_densenet_ft.trainable = True
    for layer in base_model_densenet_ft.layers[:150]:
        layer.trainable = False

    # Top model
    x = base_model_densenet_ft.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    output = Dense(1, activation='sigmoid')(x)

    model_densenet_ft = Model(inputs=base_model_densenet_ft.input, outputs=output)
    model_densenet_ft.compile(
        loss='binary_crossentropy',
        optimizer=Adam(learning_rate=learning_rate),
        metrics=['accuracy', AUC(name='auc')]
    )
    return model_densenet_ft

model_densenet_ft = build_densenet_model_ft()
model_densenet_ft.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ zero_padding2d_2          │ (None, 230, 230, 3)    │              0 │ input_layer_1[0][0]    │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_conv (Conv2D)       │ (None, 112, 112, 64)   │          9,408 │ zero_padding2d_2[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_bn                  │ (None, 112, 112, 64)   │            256 │ conv1_conv[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_relu (Activation)   │ (None, 112, 112, 64)   │              0 │ conv1_bn[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ zero_padding2d_3          │ (None, 114, 114, 64)   │              0 │ conv1_relu[0][0]       │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool1 (MaxPooling2D)      │ (None, 56, 56, 64)     │              0 │ zero_padding2d_3[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_0_bn         │ (None, 56, 56, 64)     │            256 │ pool1[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_0_relu       │ (None, 56, 56, 64)     │              0 │ conv2_block1_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_conv       │ (None, 56, 56, 128)    │          8,192 │ conv2_block1_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_bn         │ (None, 56, 56, 128)    │            512 │ conv2_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_relu       │ (None, 56, 56, 128)    │              0 │ conv2_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_2_conv       │ (None, 56, 56, 32)     │         36,864 │ conv2_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_concat       │ (None, 56, 56, 96)     │              0 │ pool1[0][0],           │
# │ (Concatenate)             │                        │                │ conv2_block1_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_0_bn         │ (None, 56, 56, 96)     │            384 │ conv2_block1_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_0_relu       │ (None, 56, 56, 96)     │              0 │ conv2_block2_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_conv       │ (None, 56, 56, 128)    │         12,288 │ conv2_block2_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_bn         │ (None, 56, 56, 128)    │            512 │ conv2_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_relu       │ (None, 56, 56, 128)    │              0 │ conv2_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_2_conv       │ (None, 56, 56, 32)     │         36,864 │ conv2_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_concat       │ (None, 56, 56, 128)    │              0 │ conv2_block1_concat[0… │
# │ (Concatenate)             │                        │                │ conv2_block2_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_0_bn         │ (None, 56, 56, 128)    │            512 │ conv2_block2_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_0_relu       │ (None, 56, 56, 128)    │              0 │ conv2_block3_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_conv       │ (None, 56, 56, 128)    │         16,384 │ conv2_block3_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_bn         │ (None, 56, 56, 128)    │            512 │ conv2_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_relu       │ (None, 56, 56, 128)    │              0 │ conv2_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_2_conv       │ (None, 56, 56, 32)     │         36,864 │ conv2_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_concat       │ (None, 56, 56, 160)    │              0 │ conv2_block2_concat[0… │
# │ (Concatenate)             │                        │                │ conv2_block3_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_0_bn         │ (None, 56, 56, 160)    │            640 │ conv2_block3_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_0_relu       │ (None, 56, 56, 160)    │              0 │ conv2_block4_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_1_conv       │ (None, 56, 56, 128)    │         20,480 │ conv2_block4_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_1_bn         │ (None, 56, 56, 128)    │            512 │ conv2_block4_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_1_relu       │ (None, 56, 56, 128)    │              0 │ conv2_block4_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_2_conv       │ (None, 56, 56, 32)     │         36,864 │ conv2_block4_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block4_concat       │ (None, 56, 56, 192)    │              0 │ conv2_block3_concat[0… │
# │ (Concatenate)             │                        │                │ conv2_block4_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_0_bn         │ (None, 56, 56, 192)    │            768 │ conv2_block4_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_0_relu       │ (None, 56, 56, 192)    │              0 │ conv2_block5_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_1_conv       │ (None, 56, 56, 128)    │         24,576 │ conv2_block5_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_1_bn         │ (None, 56, 56, 128)    │            512 │ conv2_block5_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_1_relu       │ (None, 56, 56, 128)    │              0 │ conv2_block5_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_2_conv       │ (None, 56, 56, 32)     │         36,864 │ conv2_block5_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block5_concat       │ (None, 56, 56, 224)    │              0 │ conv2_block4_concat[0… │
# │ (Concatenate)             │                        │                │ conv2_block5_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_0_bn         │ (None, 56, 56, 224)    │            896 │ conv2_block5_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_0_relu       │ (None, 56, 56, 224)    │              0 │ conv2_block6_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_1_conv       │ (None, 56, 56, 128)    │         28,672 │ conv2_block6_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_1_bn         │ (None, 56, 56, 128)    │            512 │ conv2_block6_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_1_relu       │ (None, 56, 56, 128)    │              0 │ conv2_block6_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_2_conv       │ (None, 56, 56, 32)     │         36,864 │ conv2_block6_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block6_concat       │ (None, 56, 56, 256)    │              0 │ conv2_block5_concat[0… │
# │ (Concatenate)             │                        │                │ conv2_block6_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool2_bn                  │ (None, 56, 56, 256)    │          1,024 │ conv2_block6_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool2_relu (Activation)   │ (None, 56, 56, 256)    │              0 │ pool2_bn[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool2_conv (Conv2D)       │ (None, 56, 56, 128)    │         32,768 │ pool2_relu[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool2_pool                │ (None, 28, 28, 128)    │              0 │ pool2_conv[0][0]       │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_0_bn         │ (None, 28, 28, 128)    │            512 │ pool2_pool[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_0_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block1_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_conv       │ (None, 28, 28, 128)    │         16,384 │ conv3_block1_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_bn         │ (None, 28, 28, 128)    │            512 │ conv3_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_2_conv       │ (None, 28, 28, 32)     │         36,864 │ conv3_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_concat       │ (None, 28, 28, 160)    │              0 │ pool2_pool[0][0],      │
# │ (Concatenate)             │                        │                │ conv3_block1_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_0_bn         │ (None, 28, 28, 160)    │            640 │ conv3_block1_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_0_relu       │ (None, 28, 28, 160)    │              0 │ conv3_block2_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_conv       │ (None, 28, 28, 128)    │         20,480 │ conv3_block2_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_bn         │ (None, 28, 28, 128)    │            512 │ conv3_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_2_conv       │ (None, 28, 28, 32)     │         36,864 │ conv3_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_concat       │ (None, 28, 28, 192)    │              0 │ conv3_block1_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block2_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_0_bn         │ (None, 28, 28, 192)    │            768 │ conv3_block2_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_0_relu       │ (None, 28, 28, 192)    │              0 │ conv3_block3_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_conv       │ (None, 28, 28, 128)    │         24,576 │ conv3_block3_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_bn         │ (None, 28, 28, 128)    │            512 │ conv3_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_2_conv       │ (None, 28, 28, 32)     │         36,864 │ conv3_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_concat       │ (None, 28, 28, 224)    │              0 │ conv3_block2_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block3_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_0_bn         │ (None, 28, 28, 224)    │            896 │ conv3_block3_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_0_relu       │ (None, 28, 28, 224)    │              0 │ conv3_block4_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_conv       │ (None, 28, 28, 128)    │         28,672 │ conv3_block4_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_bn         │ (None, 28, 28, 128)    │            512 │ conv3_block4_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block4_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_2_conv       │ (None, 28, 28, 32)     │         36,864 │ conv3_block4_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_concat       │ (None, 28, 28, 256)    │              0 │ conv3_block3_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block4_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_0_bn         │ (None, 28, 28, 256)    │          1,024 │ conv3_block4_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_0_relu       │ (None, 28, 28, 256)    │              0 │ conv3_block5_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_1_conv       │ (None, 28, 28, 128)    │         32,768 │ conv3_block5_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_1_bn         │ (None, 28, 28, 128)    │            512 │ conv3_block5_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_1_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block5_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_2_conv       │ (None, 28, 28, 32)     │         36,864 │ conv3_block5_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block5_concat       │ (None, 28, 28, 288)    │              0 │ conv3_block4_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block5_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_0_bn         │ (None, 28, 28, 288)    │          1,152 │ conv3_block5_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_0_relu       │ (None, 28, 28, 288)    │              0 │ conv3_block6_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_1_conv       │ (None, 28, 28, 128)    │         36,864 │ conv3_block6_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_1_bn         │ (None, 28, 28, 128)    │            512 │ conv3_block6_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_1_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block6_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_2_conv       │ (None, 28, 28, 32)     │         36,864 │ conv3_block6_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block6_concat       │ (None, 28, 28, 320)    │              0 │ conv3_block5_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block6_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_0_bn         │ (None, 28, 28, 320)    │          1,280 │ conv3_block6_concat[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_0_relu       │ (None, 28, 28, 320)    │              0 │ conv3_block7_0_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_1_conv       │ (None, 28, 28, 128)    │         40,960 │ conv3_block7_0_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_1_bn         │ (None, 28, 28, 128)    │            512 │ conv3_block7_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_1_relu       │ (None, 28, 28, 128)    │              0 │ conv3_block7_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_2_conv       │ (None, 28, 28, 32)     │         36,864 │ conv3_block7_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block7_concat       │ (None, 28, 28, 352)    │              0 │ conv3_block6_concat[0… │
# │ (Concatenate)             │                        │                │ conv3_block7_2_conv[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_
… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn (BatchNormalization)   │ (None, 7, 7, 1024)     │          4,096 │ conv5_block16_concat[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ relu (Activation)         │ (None, 7, 7, 1024)     │              0 │ bn[0][0]               │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 1024)           │              0 │ relu[0][0]             │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 1024)           │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 1024)           │          4,096 │ dropout_2[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 128)            │        131,200 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 128)            │              0 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 1)              │            129 │ dropout_3[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,172,929 (27.36 MB)
#  Trainable params: 5,586,625 (21.31 MB)
#  Non-trainable params: 1,586,304 (6.05 MB)

# %% [markdown]
# **Resumen arquitectura:**
#
# Total params: 7,172,929 (27.36 MB)
#
# Trainable params: 5,586,625 (21.31 MB)
#
# Non-trainable params: 1,586,304 (6.05 MB)

# %%
img_size = 150
batch_size = 64
learning_rate=1e-5
seeds = [0, 1, 2, 3, 4]

results_densenet_ft_list = []
histories_densenet_ft = {}
models_densenet_ft = {}

test_paths, test_labels = get_image_paths_labels(test_dir)
test_df = pd.DataFrame({'filename': test_paths, 'label': test_labels})

for seed in seeds:
    print(f"\n=== SEMILLA {seed} ===")

    tf.random.set_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    
    # Preparar datos
    train_df, val_df = get_dataframes(train_dir, val_dir, seed)
    train_generator, val_generator, test_generator = get_data_generators(train_df, val_df, test_df, img_size, batch_size, seed)
    
    # Ajuste de pesos
    class_weights = get_class_weights(train_df)
    
    # Crear modelo Custom CNN
    model_densenet_ft = build_densenet_model_ft(img_size, learning_rate)
    
    # Callbacks
    callbacks = get_callbacks()
    
    # Entrenamiento
    history_densenet_ft = model_densenet_ft.fit(
        train_generator,
        validation_data=val_generator,
        epochs=25,
        class_weight=class_weights,
        callbacks=callbacks,
    )

    histories_densenet_ft[seed] = history_densenet_ft
    models_densenet_ft[seed] = model_densenet_ft
    
    # Evaluación en test
    results_densenet_ft = model_densenet_ft.evaluate(test_generator, verbose=0)
    print(f"Test Loss: {results_densenet_ft[0]:.4f}")
    print(f"Test Accuracy: {results_densenet_ft[1]:.4f}")
    print(f"AUC: {results_densenet_ft[2]:.4f}")
    
    # Guardar resultados
    results_densenet_ft_list.append({
        'Seed': seed,
        'Test Loss': results_densenet_ft[0],
        'Test Accuracy': results_densenet_ft[1],
        'Test AUC': results_densenet_ft[2]
    })

# Mostramos resultados
df_results_densenet_ft = pd.DataFrame(results_densenet_ft_list)

plt.figure(figsize=(8, 6))
sns.boxplot(data=df_results_densenet_ft[['Test Accuracy', 'Test AUC', 'Test Loss']])
plt.title('Distribución de métricas en test (5 semillas) - DenseNet121 (FT)')
plt.grid(True)
plt.show()
# Out:
# === SEMILLA 0 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1754841447.273860     110 service.cc:148] XLA service 0x7d8444101c50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1754841447.275509     110 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1754841447.275543     110 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:
25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 964ms/step - accuracy: 0.9669 - auc: 0.9901 - loss: 0.1107 - val_accuracy: 0.9675 - val_auc: 0.9952 - val_loss: 0.0956 - learning_rate: 1.0000e-05
# Epoch 17/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 959ms/step - accuracy: 0.9635 - auc: 0.9918 - loss: 0.1061 - val_accuracy: 0.9675 - val_auc: 0.9955 - val_loss: 0.0954 - learning_rate: 1.0000e-05
# Epoch 18/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 955ms/step - accuracy: 0.9675 - auc: 0.9915 - loss: 0.1097 - val_accuracy: 0.9704 - val_auc: 0.9958 - val_loss: 0.0871 - learning_rate: 1.0000e-05
# Epoch 19/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 972ms/step - accuracy: 0.9694 - auc: 0.9926 - loss: 0.0972 - val_accuracy: 0.9704 - val_auc: 0.9965 - val_loss: 0.0829 - learning_rate: 1.0000e-05
# Epoch 20/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 953ms/step - accuracy: 0.9690 - auc: 0.9940 - loss: 0.0920 - val_accuracy: 0.9723 - val_auc: 0.9968 - val_loss: 0.0747 - learning_rate: 1.0000e-05
# Epoch 21/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 978ms/step - accuracy: 0.9747 - auc: 0.9929 - loss: 0.0885 - val_accuracy: 0.9723 - val_auc: 0.9975 - val_loss: 0.0705 - learning_rate: 1.0000e-05
# Epoch 22/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 961ms/step - accuracy: 0.9663 - auc: 0.9936 - loss: 0.0876 - val_accuracy: 0.9713 - val_auc: 0.9965 - val_loss: 0.0805 - learning_rate: 1.0000e-05
# Epoch 23/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 968ms/step - accuracy: 0.9757 - auc: 0.9953 - loss: 0.0793 - val_accuracy: 0.9723 - val_auc: 0.9971 - val_loss: 0.0703 - learning_rate: 1.0000e-05
# Epoch 24/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 948ms/step - accuracy: 0.9763 - auc: 0.9931 - loss: 0.0763 - val_accuracy: 0.9733 - val_auc: 0.9978 - val_loss: 0.0659 - learning_rate: 1.0000e-05
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 944ms/step - accuracy: 0.9797 - auc: 0.9974 - loss: 0.0609 - val_accuracy: 0.9733 - val_auc: 0.9979 - val_loss: 0.0636 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 25.
# Test Loss: 0.3144
# Test Accuracy: 0.8878
# AUC: 0.9709
#
# === SEMILLA 1 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 234s 2s/step - accuracy: 0.6971 - auc: 0.5388 - loss: 0.6421 - val_accuracy: 0.7880 - val_auc: 0.8971 - val_loss: 0.5344 - learning_rate: 1.0000e-05
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 946ms/step - accuracy: 0.7980 - auc: 0.7950 - loss: 0.4494 - val_accuracy: 0.7851 - val_auc: 0.9534 - val_loss: 0.4862 - learning_rate: 1.0000e-05
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 956ms/step - accuracy: 0.8541 - auc: 0.9010 - loss: 0.3615 - val_accuracy: 0.8300 - val_auc: 0.9679 - val_loss: 0.4178 - learning_rate: 1.0000e-05
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 952ms/step - accuracy: 0.8923 - auc: 0.9477 - loss: 0.2894 - val_accuracy: 0.8539 - val_auc: 0.9747 - val_loss: 0.3643 - learning_rate: 1.0000e-05
# Epoch 5/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s
25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 949ms/step - accuracy: 0.9694 - auc: 0.9947 - loss: 0.0891 - val_accuracy: 0.9637 - val_auc: 0.9950 - val_loss: 0.1095 - learning_rate: 1.0000e-05
# Epoch 21/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 944ms/step - accuracy: 0.9701 - auc: 0.9935 - loss: 0.0923 - val_accuracy: 0.9589 - val_auc: 0.9954 - val_loss: 0.1160 - learning_rate: 1.0000e-05
# Epoch 22/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 943ms/step - accuracy: 0.9727 - auc: 0.9942 - loss: 0.0861 - val_accuracy: 0.9570 - val_auc: 0.9960 - val_loss: 0.1188 - learning_rate: 1.0000e-05
# Epoch 23/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 944ms/step - accuracy: 0.9701 - auc: 0.9942 - loss: 0.0901 - val_accuracy: 0.9551 - val_auc: 0.9963 - val_loss: 0.1203 - learning_rate: 1.0000e-05
# Epoch 24/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 952ms/step - accuracy: 0.9734 - auc: 0.9941 - loss: 0.0791 - val_accuracy: 0.9628 - val_auc: 0.9965 - val_loss: 0.1081 - learning_rate: 1.0000e-05
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 948ms/step - accuracy: 0.9699 - auc: 0.9952 - loss: 0.0811 - val_accuracy: 0.9580 - val_auc: 0.9961 - val_loss: 0.1158 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 24.
# Test Loss: 0.2530
# Test Accuracy: 0.9087
# AUC: 0.9654
#
# === SEMILLA 2 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 233s 2s/step - accuracy: 0.2746 - auc: 0.6373 - loss: 1.4909 - val_accuracy: 0.2579 - val_auc: 0.9407 - val_loss: 2.0049 - learning_rate: 1.0000e-05
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 943ms/step - accuracy: 0.3273 - auc: 0.8291 - loss: 1.2320 - val_accuracy: 0.2646 - val_auc: 0.9576 - val_loss: 1.7886 - learning_rate: 1.0000e-05
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 953ms/step - accuracy: 0.4210 - auc: 0.9159 - loss: 0.9748 - val_accuracy: 0.3620 - val_auc: 0.9486 - val_loss: 1.5511 - learning_rate: 1.0000e-05
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 954ms/step - accuracy: 0.5629 - auc: 0.9487 - loss: 0.8021 - val_accuracy: 0.5721 - val_auc: 0.9594 - val_loss: 1.1979 - learning_rate: 1.0000e-05
# Epoch 5/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 952ms/step - accuracy: 0.7320 - auc: 0.9544 - loss: 0.6224 - val_accuracy: 0.7564 - val_auc: 0.9711 - val_loss: 0.8227 - learning_rate: 1.0000e-05
# Epoch 6/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 65s 986ms/step - accuracy: 0.8050 - auc: 0.9681 - loss: 0.5039 - val_accuracy: 0.8415 - val_auc: 0.9791 - val_loss: 0.6059 - learning_rate: 1.0000e-05
# Epoch 7/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 949ms/step - accuracy: 0.8871 - auc: 0.9764 - loss: 0.3627 - val_accuracy: 0.8816 - val_auc: 0.9830 - val_loss: 0.4637 - learning_rate: 1.0000e-05
# Epoch 8/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 65s 986ms/step - accuracy: 0.9085 - auc: 0.9717 - loss: 0.3446 - val_accuracy: 0.9217 - val_auc: 0.9864 - val_loss: 0.3317 - learning_rate: 1.0000e-05
# Epoch 9/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s
25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 943ms/step - accuracy: 0.9735 - auc: 0.9938 - loss: 0.0843 - val_accuracy: 0.9666 - val_auc: 0.9946 - val_loss: 0.1162 - learning_rate: 1.0000e-05
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 953ms/step - accuracy: 0.9700 - auc: 0.9902 - loss: 0.1004 - val_accuracy: 0.9685 - val_auc: 0.9957 - val_loss: 0.1067 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 25.
# Test Loss: 0.2733
# Test Accuracy: 0.9006
# AUC: 0.9723
#
# === SEMILLA 3 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 238s 2s/step - accuracy: 0.5374 - auc: 0.5347 - loss: 0.7848 - val_accuracy: 0.5358 - val_auc: 0.8107 - val_loss: 0.6997 - learning_rate: 1.0000e-05
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 937ms/step - accuracy: 0.6863 - auc: 0.7711 - loss: 0.5957 - val_accuracy: 0.6237 - val_auc: 0.9678 - val_loss: 0.6245 - learning_rate: 1.0000e-05
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 937ms/step - accuracy: 0.7711 - auc: 0.8973 - loss: 0.4732 - val_accuracy: 0.7182 - val_auc: 0.9821 - val_loss: 0.5623 - learning_rate: 1.0000e-05
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 941ms/step - accuracy: 0.8271 - auc: 0.9317 - loss: 0.4117 - val_accuracy: 0.8204 - val_auc: 0.9861 - val_loss: 0.4573 - learning_rate: 1.0000e-05
# Epoch 5/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 939ms/step - accuracy: 0.8756 - auc: 0.9585 - loss: 0.3400 - val_accuracy: 0.8443 - val_auc: 0.9881 - val_loss: 0.4099 - learning_rate: 1.0000e-05
# Epoch 6/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 939ms/step - accuracy: 0.8970 - auc: 0.9650 - loss: 0.3025 - val_accuracy: 0.8749 - val_auc: 0.9892 - val_loss: 0.3474 - learning_rate: 1.0000e-05
# Epoch 7/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 936ms/step - accuracy: 0.9185 - auc: 0.9694 - loss: 0.2497 - val_accuracy: 0.8968 - val_auc: 0.9905 - val_loss: 0.2880 - learning_rate: 1.0000e-05
# Epoch 8/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 937ms/step - accuracy: 0.9226 - auc: 0.9681 - loss: 0.2392 - val_accuracy: 0.9217 - val_auc: 0.9914 - val_loss: 0.2334 - learning_rate: 1.0000e-05
# Epoch 9/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 958ms/step - accuracy: 0.9311 - auc: 0.9829 - loss: 0.1916 - val_accuracy: 0.9341 - val_auc: 0.9922 - val_loss: 0.2008 - learning_rate: 1.0000e-05
# Epoch 10/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 966ms/step - accuracy: 0.9356 - auc: 0.9756 - loss: 0.2038 - val_accuracy: 0.9398 - val_auc: 0.9926 - val_loss: 0.1791 - learning_rate: 1.0000e-05
# Epoch 11/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 960ms/step - accuracy: 0.9407 - auc: 0.9803 - loss: 0.1779 - val_accuracy: 0.9465 - val_auc: 0.9925 - val_loss: 0.1649 - learning_rate: 1.0000e-05
# Epoch 12/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 963ms/step - accuracy: 0.9512 - auc: 0.9855 - loss: 0.1572 - val_accuracy: 0.9513 - val_auc: 0.9934 - val_loss: 0.1443 - learning_rate: 1.0000e-05
# Epoch 13/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 955ms/step - accuracy: 0.9437 - auc: 0.9835 - loss: 0.1545 - val_accuracy: 0.9589 - val_auc: 0.9939 - val_loss: 0.1334 - learning_rate: 1.0000e-05
# Epoch 14/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 948ms/step - accuracy: 0.9490 - auc: 0.9836 - loss: 0.1535 - val_accuracy: 0.9608 - val_auc: 0.9933 - val_loss: 0.1255 - learning_rate: 1.0000e-05
# Epoch 15/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 952ms/step - accuracy: 0.9525 - auc: 0.9854 - loss: 0.1434 - val_accuracy: 0.9685 - val_auc: 0.9940 - val_loss: 0.1124 - learning_rate: 1.0000e-05
# Epoch 16/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 949ms/step - accuracy: 0.9604 - auc: 0.9885 - loss: 0.1201 - val_accuracy: 0.9694 - val_auc: 0.9944 - val_loss: 0.1090 - learning_rate: 1.0000e-05
# Epoch 17/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 951ms/step - accuracy: 0.9577 - auc: 0.9913 - loss: 0.1138 - val_accuracy: 0.9675 - val_auc: 0.9943 - val_loss: 0.1058 - learning_rate: 1.0000e-05
# Epoch 18/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 957ms/step - accuracy: 0.9602 - auc: 0.9886 - loss: 0.1238 - val_accuracy: 0.9752 - val_auc: 0.9952 - val_loss: 0.0918 - learning_rate: 1.0000e-05
# Epoch 19/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 949ms/step - accuracy: 0.9642 - auc: 0.9911 - loss: 0.1065 - val_accuracy: 0.9704 - val_auc: 0.9955 - val_loss: 0.0921 - learning_rate: 1.0000e-05
# Epoch 20/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 956ms/step - accuracy: 0.9610 - auc: 0.9898 - loss: 0.1138 - val_accuracy: 0.9733 - val_auc: 0.9956 - val_loss: 0.0859 - learning_rate: 1.0000e-05
# Epoch 21/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 941ms/step - accuracy: 0.9642 - auc: 0.9889 - loss: 0.1142 - val_accuracy: 0.9694 - val_auc: 0.9959 - val_loss: 0.0902 - learning_rate: 1.0000e-05
# Epoch 22/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 953ms/step - accuracy: 0.9641 - auc: 0.9900 - loss: 0.1011 - val_accuracy: 0.9733 - val_auc: 0.9962 - val_loss: 0.0825 - learning_rate: 1.0000e-05
# Epoch 23/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 943ms/step - accuracy: 0.9734 - auc: 0.9933 - loss: 0.0875 - val_accuracy: 0.9713 - val_auc: 0.9963 - val_loss: 0.0861 - learning_rate: 1.0000e-05
# Epoch 24/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 945ms/step - accuracy: 0.9739 - auc: 0.9939 - loss: 0.0821 - val_accuracy: 0.9675 - val_auc: 0.9960 - val_loss: 0.0931 - learning_rate: 1.0000e-05
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 936ms/step - accuracy: 0.9742 - auc: 0.9947 - loss: 0.0867 - val_accuracy: 0.9694 - val_auc: 0.9967 - val_loss: 0.0873 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 25.
# Test Loss: 0.2574
# Test Accuracy: 0.9103
# AUC: 0.9714
#
# === SEMILLA 4 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 238s 2s/step - accuracy: 0.4722 - auc: 0.5497 - loss: 0.8744 - val_accuracy: 0.6246 - val_auc: 0.7000 - val_loss: 0.6408 - learning_rate: 1.0000e-05
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s
25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 952ms/step - accuracy: 0.9672 - auc: 0.9909 - loss: 0.1059 - val_accuracy: 0.9532 - val_auc: 0.9937 - val_loss: 0.1259 - learning_rate: 1.0000e-05
# Epoch 18/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 951ms/step - accuracy: 0.9578 - auc: 0.9824 - loss: 0.1379 - val_accuracy: 0.9561 - val_auc: 0.9939 - val_loss: 0.1189 - learning_rate: 1.0000e-05
# Epoch 19/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 944ms/step - accuracy: 0.9629 - auc: 0.9916 - loss: 0.1083 - val_accuracy: 0.9580 - val_auc: 0.9946 - val_loss: 0.1108 - learning_rate: 1.0000e-05
# Epoch 20/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 958ms/step - accuracy: 0.9677 - auc: 0.9925 - loss: 0.0955 - val_accuracy: 0.9561 - val_auc: 0.9951 - val_loss: 0.1159 - learning_rate: 1.0000e-05
# Epoch 21/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 943ms/step - accuracy: 0.9644 - auc: 0.9906 - loss: 0.1068 - val_accuracy: 0.9542 - val_auc: 0.9954 - val_loss: 0.1151 - learning_rate: 1.0000e-05
# Epoch 22/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 939ms/step - accuracy: 0.9726 - auc: 0.9931 - loss: 0.0879 - val_accuracy: 0.9580 - val_auc: 0.9953 - val_loss: 0.1061 - learning_rate: 1.0000e-05
# Epoch 23/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 937ms/step - accuracy: 0.9719 - auc: 0.9936 - loss: 0.0915 - val_accuracy: 0.9580 - val_auc: 0.9956 - val_loss: 0.1090 - learning_rate: 1.0000e-05
# Epoch 24/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 63s 949ms/step - accuracy: 0.9753 - auc: 0.9923 - loss: 0.0828 - val_accuracy: 0.9561 - val_auc: 0.9957 - val_loss: 0.1140 - learning_rate: 1.0000e-05
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 62s 945ms/step - accuracy: 0.9726 - auc: 0.9941 - loss: 0.0809 - val_accuracy: 0.9570 - val_auc: 0.9960 - val_loss: 0.1174 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 25.
# Test Loss: 0.2734
# Test Accuracy: 0.8894
# AUC: 0.9667

# %%
# Elegimos semilla
history_densenet_ft = histories_densenet_ft[3] 

# Accuracy
plt.plot(history_densenet_ft.history['accuracy'], label='Entrenamiento')
plt.plot(history_densenet_ft.history['val_accuracy'], label='Validación')
plt.title('Precisión (Accuracy)')
plt.xlabel('Época')
plt.ylabel('Precisión')
plt.legend()
plt.grid(True)
plt.show()

# Loss
plt.plot(history_densenet_ft.history['loss'], label='Entrenamiento')
plt.plot(history_densenet_ft.history['val_loss'], label='Validación')
plt.title('Pérdida (Loss)')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Evaluación del Rendimiento DenseNet**

# %% [markdown]
# ### **DenseNet121 con Feature Extraction**

# %%
# Elegimos la semilla para ver las métricas de esa ejecución
y_true, y_pred, y_pred_probs = evaluar_modelo(models_densenet[4], test_generator, nombre_modelo="DenseNet121 (Feature Extraction)")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step
# Métricas de Clasificación - DenseNet121 (Feature Extraction)
#               precision    recall  f1-score   support
#
#       NORMAL       0.93      0.79      0.86       234
#    PNEUMONIA       0.89      0.96      0.92       390
#
#     accuracy                           0.90       624
#    macro avg       0.91      0.88      0.89       624
# weighted avg       0.90      0.90      0.90       624
#
# AUC-ROC: 0.9540
# Especificidad: 0.7949

# %% [markdown]
# #### **Matriz de Confusión:**
# * #### Clasifica correctamente la mayoría de los casos de **PNEUMONIA**: 376 sobre 390.
# * #### También se clasifican adecuadamente la mayoría de las imágenes **NORMALES**: 186 aciertos sobre 234.
#
# #### **Métricas de Clasificación:**
#
# #### **1. Precisión**
#
# * #### NORMAL → 0.93. El 93% de las veces que el modelo predice que es normal, acierta.
# * #### PNEUMONIA → 0.89. El 89% de las veces que predice neumonía, acierta.
#
# #### **2. Recall (Sensibilidad)**
#
# * #### NORMAL → 0.79. El modelo detecta correctamente el 79% de las imágenes normales.
# * #### PNEUMONIA → 0.96. El modelo identifica correctamente el 96% de los casos con neumonía, lo cual es muy relevante en diagnóstico médico.
#
# #### **3. F1-Score**
#  * #### Buen equilibrio entre precisión y sensibilidad, especialmente alto en la clase neumonía (0.92), lo que refuerza su utilidad diagnóstica.
#
# #### **4. Accuracy**
# * #### Precisión global del modelo: 0.90. Es un valor alto y consistente. Dado que el dataset está balanceado, esta métrica es representativa.
#
# #### **AUC-ROC (0.9540):** Indica excelente capacidad del modelo para distinguir entre ambas clases. Cuanto más cerca de 1, mejor.
#
# #### **Especificidad (0.7949):** Mide la capacidad del modelo para identificar correctamente los casos normales. Este valor, aunque más bajo que el recall de la clase neumonía, es esperable en entornos médicos donde se prioriza reducir falsos negativos sobre falsos positivos.

# %% [markdown]
# ### **DenseNet121 con Fine-Tuning**

# %% [markdown]
# #### Fine-tuning ha mejorado algo la media de los valores. Siendo la mayoria en Feature Extraction un porcentaje de accuracy algo superior de 88, y en Fine-tuning superior a 90

# %%
# Elegimos la semilla para ver las métricas de esa ejecución
y_true, y_pred, y_pred_probs = evaluar_modelo(models_densenet_ft[3], test_generator, nombre_modelo="DenseNet121 (Fine-Tuning)")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 420ms/step
# Métricas de Clasificación - DenseNet121 (Fine-Tuning)
#               precision    recall  f1-score   support
#
#       NORMAL       0.98      0.78      0.87       234
#    PNEUMONIA       0.88      0.99      0.93       390
#
#     accuracy                           0.91       624
#    macro avg       0.93      0.88      0.90       624
# weighted avg       0.92      0.91      0.91       624
#
# AUC-ROC: 0.9722
# Especificidad: 0.7778

# %% [markdown]
# #### **Matriz de Confusión:**
# * #### Clasifica correctamente la mayoría de los casos de PNEUMONIA: 386 sobre 390.
# * #### También se clasifican adecuadamente la mayoría de las imágenes NORMALES: 182 aciertos sobre 234.
#
# #### **Métricas de Clasificación:**
#
# #### **1. Precisión**
#
# * #### NORMAL →  0.98. El 98% de las veces que el modelo predice que es normal, acierta.
# * #### PNEUMONIA → 0.88. El 88% de las veces que predice neumonía, acierta.
#
# #### **2. Recall (Sensibilidad)**
#
# * #### NORMAL → 0.78. El modelo detecta correctamente el 78% de las imágenes normales.
# * #### PNEUMONIA →  0.99. El modelo identifica correctamente el 99% de los casos con neumonía, lo cual es extremadamente relevante en diagnóstico médico.
#
# #### **3. F1-Score**
#  * #### Buen equilibrio entre precisión y sensibilidad, especialmente alto en la clase neumonía (0.93), lo que refuerza su utilidad diagnóstica.
#
# #### **4. Accuracy**
# * #### Precisión global del modelo: 0.91. Es un valor alto y consistente. Dado que el dataset está balanceado, esta métrica es representativa.
#
# #### **AUC-ROC (0.9722):** Indica excelente capacidad del modelo para distinguir entre ambas clases. Cuanto más cerca de 1, mejor.
#
# #### **Especificidad (0.7778):** Mide la capacidad del modelo para identificar correctamente los casos normales. Este valor, aunque más bajo que el recall de la clase neumonía, es esperable en entornos médicos donde se prioriza reducir falsos negativos sobre falsos positivos.

# %% [markdown]
# ## **Entrenamiento del Modelo 3: ResNet101**

# %% [markdown]
# #### Para este modelo se han realizado múltiples pruebas y ajustes, como se detallará más adelante. Dado que los resultados no han sido tan satisfactorios como con otros enfoques, se podría contemplar el uso de alternativas distintas a las arquitecturas CNN puras. Existe la posibilidad de utilizar **ResNet101 únicamente como extractor de características** (feature extractor), y conectar su salida a un **clasificador tradicional** de machine learning, como **SVM, Random Forest o XGBoost**.
#
# #### En este caso sería un modelo hídrido, pues mezcla un modelo clásico de ML con redes neuronales. Esta estrategia hídrida puede funcionar mejor cuando se trabaja con datasets pequeños y puede aportar una menor complejidad del modelo y menor riesgo de sobreajuste.

# %% [markdown]
# ## **Feature Extraction R**

# %% [markdown]
# ### **Modelo base**
# #### Mismo procedimiento que para DenseNet121. ResNet101 tiene 101 capas efectivas, es decir, con pesos ajustables que contribuyen al aprendizaje. A pesar de tener menos capas efectivas que DenseNet121, estás tiene mas parámetros, por lo que existe mayor riesgo de overfitting en este modelo.
#
# #### Como particularidad, este modelo utiliza **residual connections** que es lo que le da su propio nombre: ResNet (Residual Network). Para ello utiliza unas capas **Add()** que se usan dentro del extractor convolucional para facilitar el entrenamiento (evitan el *vanishing gradient*).
#
# ### **Top model**
# #### Inicialmente, para hacer una comparación "justa" con DenseNet121, se utilizó la misma arquitectura de capa de clasificación ("top model") sobre ResNet101. Mismo ajuste de capas densas, dropout y normalización.
#
# #### Sin embargo, los resultados obtenidos con esta configuración fueron inferiores en ResNet101, lo que indicaba que esta arquitectura no se ajusta de manera óptima a las características internas de este modelo.
#
# #### Se probaron múltiples arquitecturas de top model para ResNet101, fue finalmente una arquitectura más profunda y compleja la que mejor resultado ofreció. En principio, una arquitectura mas simple es lo recomendable pues:
# * #### Al ser un dataset pequeño, un top model demasiado profundo con mas neuronas, equivale a mas parámetros adicionales, lo que facilita que el modelo memorize en vez de aprender patrones generales.
# #### El motivo por el que una arquitectura mas profunda ha podido dar mejores resultados son los siguientes:
# * #### **Regularización efectiva:** la arquitectura incluye varias capas de Dropout y BatchNormalization, que ayuda a controlar el sobreajuste incluso con un número mayor de parámetros.
# * #### **Mejoras del dataset:** tanto el ajuste del balanceo como el data augmentation aplicado, ofrece mas variabilidad de los datos, lo que permite aprovechar los features del modelo sin caer en sobreajuste.
#
# #### **Funciones de activación ¿ReLU o Swish?**
# #### Tambien se probó con estas diferentes funciones matemáticas (aplicadas a salida de las neuronas). En principio Swish es una activación que ha demostrado superar a ReLU en tareas de visión.
# #### La diferencia es que en **ReLU**, si el valor es positivo lo deja pasar, si en negativo lo convierte a 0. Rápido de calcular y funciona muy bien en la mayoría de problemas, sin embargo, en regiones negativas los flujos de gradiente pueden no ser suaves, y algunas neuronas pueden morir (quedarse siempre en 0).
#
# #### **Swish** en cambio, deja pasar suavemente valores negativos en lugar de dejarlos a 0. No mata neuronas (mejor flujo de gradiente). No siempre mejora respecto a ReLU, aunque se supone que en redes grandes o profundas si se nota mejoría.
# #### En DenseNet no se valoró porque la red fue originalmente diseñada con ReLU, tiene conexiones densas y el flujo de gradiente ya es de por sí muy bueno (junto con otras características).
#
# #### A pesar de sus beneficios, en la práctica no ha dado una mejora del rendimiento, al menos para este dataset, modelo (ResNet101), y arquitectura de la capa de clasificación empleada. Posibles motivos:
# * #### Uso de BatchNormalization: estabiliza los gradientes.
# * #### ResNet ya tiene buenas propiedades de flujo de información (residual connections).
# * #### Swish puede requerir más datos y mayor diversidad para mostrar su superioridad. En datasets no masivos o con cierto desbalance, la menor complejidad de ReLU puede ayudar.
# * #### Aunque ciertos estudios han demostrado que Swish tiende a superar a ReLU en redes profundas y tareas complejas, también se ha observado que la diferencia suele ser pequeña y depende del ajuste de hiperparámetros, la regularización y la calidad del preprocesamiento.

# %%
def build_resnet_model(img_size=150):
    # Modelo base
    base_model_resnet = ResNet101(weights='imagenet',include_top=False,input_shape=(img_size, img_size, 3))
    base_model_resnet.trainable = False

    # Top model
    x = base_model_resnet.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.4)(x)
    x = BatchNormalization()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.2)(x)
    output = Dense(1, activation='sigmoid')(x)  
    
    model_resnet = Model(inputs=base_model_resnet.input, outputs=output)
    
    model_resnet.compile(
        loss='binary_crossentropy',
        optimizer='adam',
        metrics=['accuracy', AUC(name='auc')]
    )
    return model_resnet

model_resnet = build_resnet_model()
model_resnet.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 150, 150, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_pad (ZeroPadding2D) │ (None, 156, 156, 3)    │              0 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_conv (Conv2D)       │ (None, 75, 75, 64)     │          9,472 │ conv1_pad[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_bn                  │ (None, 75, 75, 64)     │            256 │ conv1_conv[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_relu (Activation)   │ (None, 75, 75, 64)     │              0 │ conv1_bn[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool1_pad (ZeroPadding2D) │ (None, 77, 77, 64)     │              0 │ conv1_relu[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool1_pool (MaxPooling2D) │ (None, 38, 38, 64)     │              0 │ pool1_pad[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_conv       │ (None, 38, 38, 64)     │          4,160 │ pool1_pool[0][0]       │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_bn         │ (None, 38, 38, 64)     │            256 │ conv2_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_relu       │ (None, 38, 38, 64)     │              0 │ conv2_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_2_conv       │ (None, 38, 38, 64)     │         36,928 │ conv2_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_2_bn         │ (None, 38, 38, 64)     │            256 │ conv2_block1_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_2_relu       │ (None, 38, 38, 64)     │              0 │ conv2_block1_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_0_conv       │ (None, 38, 38, 256)    │         16,640 │ pool1_pool[0][0]       │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_3_conv       │ (None, 38, 38, 256)    │         16,640 │ conv2_block1_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_0_bn         │ (None, 38, 38, 256)    │          1,024 │ conv2_block1_0_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_3_bn         │ (None, 38, 38, 256)    │          1,024 │ conv2_block1_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_add (Add)    │ (None, 38, 38, 256)    │              0 │ conv2_block1_0_bn[0][… │
# │                           │                        │                │ conv2_block1_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_out          │ (None, 38, 38, 256)    │              0 │ conv2_block1_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_conv       │ (None, 38, 38, 64)     │         16,448 │ conv2_block1_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_bn         │ (None, 38, 38, 64)     │            256 │ conv2_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_relu       │ (None, 38, 38, 64)     │              0 │ conv2_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_2_conv       │ (None, 38, 38, 64)     │         36,928 │ conv2_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_2_bn         │ (None, 38, 38, 64)     │            256 │ conv2_block2_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_2_relu       │ (None, 38, 38, 64)     │              0 │ conv2_block2_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_3_conv       │ (None, 38, 38, 256)    │         16,640 │ conv2_block2_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_3_bn         │ (None, 38, 38, 256)    │          1,024 │ conv2_block2_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_add (Add)    │ (None, 38, 38, 256)    │              0 │ conv2_block1_out[0][0… │
# │                           │                        │                │ conv2_block2_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_out          │ (None, 38, 38, 256)    │              0 │ conv2_block2_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_conv       │ (None, 38, 38, 64)     │         16,448 │ conv2_block2_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_bn         │ (None, 38, 38, 64)     │            256 │ conv2_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_relu       │ (None, 38, 38, 64)     │              0 │ conv2_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_2_conv       │ (None, 38, 38, 64)     │         36,928 │ conv2_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_2_bn         │ (None, 38, 38, 64)     │            256 │ conv2_block3_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_2_relu       │ (None, 38, 38, 64)     │              0 │ conv2_block3_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_3_conv       │ (None, 38, 38, 256)    │         16,640 │ conv2_block3_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_3_bn         │ (None, 38, 38, 256)    │          1,024 │ conv2_block3_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_add (Add)    │ (None, 38, 38, 256)    │              0 │ conv2_block2_out[0][0… │
# │                           │                        │                │ conv2_block3_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_out          │ (None, 38, 38, 256)    │              0 │ conv2_block3_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_conv       │ (None, 19, 19, 128)    │         32,896 │ conv2_block3_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_bn         │ (None, 19, 19, 128)    │            512 │ conv3_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_relu       │ (None, 19, 19, 128)    │              0 │ conv3_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_2_conv       │ (None, 19, 19, 128)    │        147,584 │ conv3_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_2_bn         │ (None, 19, 19, 128)    │            512 │ conv3_block1_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_2_relu       │ (None, 19, 19, 128)    │              0 │ conv3_block1_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_0_conv       │ (None, 19, 19, 512)    │        131,584 │ conv2_block3_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_3_conv       │ (None, 19, 19, 512)    │         66,048 │ conv3_block1_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_0_bn         │ (None, 19, 19, 512)    │          2,048 │ conv3_block1_0_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_3_bn         │ (None, 19, 19, 512)    │          2,048 │ conv3_block1_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_add (Add)    │ (None, 19, 19, 512)    │              0 │ conv3_block1_0_bn[0][… │
# │                           │                        │                │ conv3_block1_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_out          │ (None, 19, 19, 512)    │              0 │ conv3_block1_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_conv       │ (None, 19, 19, 128)    │         65,664 │ conv3_block1_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_bn         │ (None, 19, 19, 128)    │            512 │ conv3_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_relu       │ (None, 19, 19, 128)    │              0 │ conv3_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_2_conv       │ (None, 19, 19, 128)    │        147,584 │ conv3_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_2_bn         │ (None, 19, 19, 128)    │            512 │ conv3_block2_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2
block2_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_3_conv       │ (None, 10, 10, 1024)   │        263,168 │ conv4_block2_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_3_bn         │ (None, 10, 10, 1024)   │          4,096 │ conv4_block2_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_add (Add)    │ (None, 10, 10, 1024)   │              0 │ conv4_block1_out[0][0… │
# │                           │                        │                │ conv4_block2_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_out          │ (None, 10, 10, 1024)   │              0 │ conv4_block2_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_1_conv       │ (None, 10, 10, 256)    │        262,400 │ conv4_block2_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_1_bn         │ (None, 10, 10, 256)    │          1,024 │ conv4_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_1_relu       │ (None, 10, 10, 256)    │              0 │ conv4_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_2_conv       │ (None, 10, 10, 256)    │        590,080 │ conv4_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_2_bn         │ (None, 10, 10, 256)    │          1,024 │ conv4_block3_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_2_relu       │ (None, 10, 10, 256)    │              0 │ conv4_block3_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_3_conv       │ (None, 10, 10, 1024)   │        263,168 │ conv4_block3_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_3_bn         │ (None, 10, 10, 1024)   │          4,096 │ conv4_block3_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_add (Add)    │ (None, 10, 10, 1024)   │              0 │ conv4_block2_out[0][0… │
# │                           │                        │                │ conv4_block3_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_out          │ (None, 10, 10, 1024)   │              0 │ conv4_block3_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_1_conv       │ (None, 10, 10, 256)    │        262,400 │ conv4_block3_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_1_bn         │ (None, 10, 10, 256)    │          1,024 │ conv4_block4_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_1_relu       │ (None, 10, 10, 256)    │              0 │ conv4_block4_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_2_conv       │ (None, 10, 10, 256)    │        590,080 │ conv4_block4_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_2_bn         │ (None, 10, 10, 256)    │          1,024 │ conv4_block4_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_2_relu       │ (None, 10, 10, 256)    │              0 │ conv4_block4_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_3_conv       │ (None, 10, 10, 1024)   │        263,168 │ conv4_block4_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_3_bn         │ (None, 10, 10, 1024)   │          4,096 │ conv4_block4_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_add (Add)    │ (None, 10, 10, 1024)   │              0 │ conv4_block3_out[0][0… │
# │                           │                        │                │ conv4_block4_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_out          │ (None, 10, 10, 1024)   │              0 │ conv4_block4_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_1_conv       │ (None, 10, 10, 256)    │        262,400 │ conv4_block4_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_1_bn         │ (None, 10, 10, 256)    │          1,024 │ conv4_block5_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_1_relu       │ (None, 10, 10, 256)    │              0 │ conv4_block5_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_2_conv       │ (None, 10, 10, 256)    │        590,080 │ conv4_block5_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_2_bn         │ (None, 10, 10, 256)    │          1,024 │ conv4_block5_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_2_relu       │ (None, 10, 10, 256)    │              0 │ conv4_block5_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_3_conv       │ (None, 10, 10, 1024)   │        263,168 │ conv4_block5_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_3_bn         │ (None, 10, 10, 1024)   │          4,096 │ conv4_block5_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_add (Add)    │ (None, 10, 10, 1024)   │              0 │ conv4_block4_out[0][0… │
# │                           │                        │                │ conv4_block5_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_out          │ (None, 10, 10, 1024)   │              0 │ conv4_block5_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_1_conv       │ (None, 10, 10, 256)    │        262,400 │ conv4_block5_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_1_bn         │ (None, 10, 10, 256)    │          1,024 │ conv4_block6_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_1_relu       │ (None, 10, 10, 256)    │              0 │ conv4_block6_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_2_conv       │ (None, 10, 10, 256)    │        590,080 │ conv4_block6_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_2_bn         │ (None, 10, 10, 256)    │          1,024 │ conv4_block6_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_2_relu       │ (None, 10, 10, 256)    │              0 │ conv4_block6_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_3_conv       │ (None, 10, 10, 1024)   │        263,168 │ conv4_block6_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_3_bn         │ (None, 10, 10, 1024)   │          4,096 │ conv4_block6_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_add (Add)    │ (None, 10, 10, 1024)   │              0 │ conv4_block5_out[0][0… │
# │                           │                        │                │ conv4_block6_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_out          │ (None, 10, 10, 1024)   │              0 │ conv4_block6_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_1_conv       │ (None, 10, 10, 256)    │        262,400 │ conv4_block6_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_1_bn         │ (None, 10, 10, 256)    │          1,024 │ conv4_block7_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_1_relu       │ (None, 10, 10, 256)    │              0 │ conv4_block7_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_2_conv       │ (None, 10, 10, 256)    │        590,080 │ conv4_block7_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_2_bn         │ (None, 10, 10, 256)    │          1,024 │ conv4_block7_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_2_relu       │ (None, 10, 10, 256)    │              0 │ conv4_block7_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_3_conv       │ (None, 10, 10, 1024)   │        263,168 │ conv4_block7_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_3_bn         │ (None, 10, 10, 1024)   │          4,096 │ conv4_block7_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_add (Add)    │ (None, 10, 10, 1024)   │              0 │ conv4_block6_out[0][0… │
# │                           │                        │                │ conv4_block7_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_out          │ (None, 10, 10, 1024)   │              0 │ conv4_block7_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_1_conv       │ (None, 10, 10, 256)    │        262,400 │ conv4_block7_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_1_bn         │ (None, 10, 10, 256)    │          1,024 │ conv4_block8_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_1_relu       │ (None, 10, 10, 256)    │              0 │ conv4_block8_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_2_conv       │ (None, 10, 10, 256)    │        590,080 │ conv4_block8_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_2_bn         │ (None, 10, 10, 256)    │          1,024 │ conv4_block8_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_2_relu       │ (None, 10, 10, 256)    │              0 │ conv4_block8_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_3_conv       │ (None, 10, 10, 1024)   │        263,168 │ conv4_block8_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_3_bn         │ (None, 10, 10, 1024)   │          4,096 │ conv4_block8_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_add (Add)    │ (None, 10, 10, 1024)   │              0 │ conv4_block7_out[0][0… │
# │                           │                        │                │ conv4_block8_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_out          │ (None, 10, 10, 1024)   │              0 │ conv4_block8_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block9_1_conv       │ (None, 10, 10, 256)    │        262,400 │ conv4_block8_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block9_1_bn         │ (None, 10, 10, 256)    │          1,024 │ conv4_block9_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block9_1_relu       │ (None, 10, 10, 256)    │              0 │ conv4_block9_1_bn[0][… │
# ...
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block22_3_conv      │ (None, 10, 10, 1024)   │        263,168 │ conv4_block22_2_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block22_3_bn        │ (None, 10, 10, 1024)   │          4,096 │ conv4_block22_3_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block22_add (Add)   │ (None, 10, 10, 1024)   │              0 │ conv4_block21_out[0][… │
# │                           │                        │                │ conv4_block22_3_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block22_out         │ (None, 10, 10, 1024)   │              0 │ conv4_block22_add[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block23_1_conv      │ (None, 10, 10, 256)    │        262,400 │ conv4_block22_out[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block23_1_bn        │ (None, 10, 10, 256)    │          1,024 │ conv4_block23_1_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block23_1_relu      │ (None, 10, 10, 256)    │              0 │ conv4_block23_1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block23_2_conv      │ (None, 10, 10, 256)    │        590,080 │ conv4_block23_1_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block23_2_bn        │ (None, 10, 10, 256)    │          1,024 │ conv4_block23_2_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block23_2_relu      │ (None, 10, 10, 256)    │              0 │ conv4_block23_2_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_
normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 128)            │              0 │ dense_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 64)             │          8,256 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 64)             │              0 │ dense_6[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 1)              │             65 │ dropout_5[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 43,233,153 (164.92 MB)
#  Trainable params: 570,369 (2.18 MB)
#  Non-trainable params: 42,662,784 (162.75 MB)

# %% [markdown]
# **Resumen arquitectura:**
#
# Total params: 43,233,153 (164.92 MB)
#
# Trainable params: 570,369 (2.18 MB)
#
# Non-trainable params: 42,662,784 (162.75 MB)

# %%
img_size = 150
batch_size = 64
seeds = [0, 1, 2, 3, 4]

results_resnet_list = []
histories_resnet = {}
models_resnet = {}

test_paths, test_labels = get_image_paths_labels(test_dir)
test_df = pd.DataFrame({'filename': test_paths, 'label': test_labels})

for seed in seeds:
    print(f"\n=== SEMILLA {seed} ===")

    tf.random.set_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    
    # Preparar datos
    train_df, val_df = get_dataframes(train_dir, val_dir, seed)
    train_generator, val_generator, test_generator = get_data_generators(train_df, val_df, test_df, img_size, batch_size, seed)
    
    # Ajuste de pesos
    class_weights = get_class_weights(train_df)
    
    # Crear modelo Custom CNN
    model_resnet = build_resnet_model(img_size)
    
    # Callbacks
    callbacks = get_callbacks()
    
    # Entrenamiento
    history_resnet = model_resnet.fit(
        train_generator,
        validation_data=val_generator,
        epochs=25,
        class_weight=class_weights,
        callbacks=callbacks,
    )

    histories_resnet[seed] = history_resnet
    models_resnet[seed] = model_resnet
    
    # Evaluación en test
    results_resnet = model_resnet.evaluate(test_generator, verbose=0)
    print(f"Test Loss: {results_resnet[0]:.4f}")
    print(f"Test Accuracy: {results_resnet[1]:.4f}")
    print(f"AUC: {results_resnet[2]:.4f}")
    
    # Guardar resultados
    results_resnet_list.append({
        'Seed': seed,
        'Test Loss': results_resnet[0],
        'Test Accuracy': results_resnet[1],
        'Test AUC': results_resnet[2]
    })

# Mostramos resultados
df_results_resnet = pd.DataFrame(results_resnet_list)

plt.figure(figsize=(8, 6))
sns.boxplot(data=df_results_resnet[['Test Accuracy', 'Test AUC', 'Test Loss']])
plt.title('Distribución de métricas en test (5 semillas) - Resnet101 (FE)')
plt.grid(True)
plt.show()
# Out:
# === SEMILLA 0 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1754911837.354292     104 service.cc:148] XLA service 0x7cd770003550 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1754911837.355071     104 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1754911837.355093     104 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1754911840.591663     104 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1754911848.913090     104 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 146s 2s/step - accuracy: 0.7905 - auc: 0.8098 - loss: 0.4444 - val_accuracy: 0.7822 - val_auc: 0.8931 - val_loss: 0.5676 - learning_rate: 0.0010
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8720 - auc: 0.9320 - loss: 0.2893 - val_accuracy: 0.7536 - val_auc: 0.9396 - val_loss: 0.4929 - learning_rate: 0.0010
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0
25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 65s 978ms/step - accuracy: 0.9177 - auc: 0.9659 - loss: 0.2030 - val_accuracy: 0.9274 - val_auc: 0.9851 - val_loss: 0.1777 - learning_rate: 3.0000e-04
# Epoch 20/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 995ms/step - accuracy: 0.9280 - auc: 0.9678 - loss: 0.1953 - val_accuracy: 0.9351 - val_auc: 0.9854 - val_loss: 0.1593 - learning_rate: 3.0000e-04
# Epoch 21/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 65s 991ms/step - accuracy: 0.9143 - auc: 0.9668 - loss: 0.2021 - val_accuracy: 0.9293 - val_auc: 0.9848 - val_loss: 0.1792 - learning_rate: 3.0000e-04
# Epoch 22/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 65s 983ms/step - accuracy: 0.9273 - auc: 0.9707 - loss: 0.1918 - val_accuracy: 0.9446 - val_auc: 0.9862 - val_loss: 0.1443 - learning_rate: 3.0000e-04
# Epoch 23/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 65s 978ms/step - accuracy: 0.9244 - auc: 0.9670 - loss: 0.1994 - val_accuracy: 0.9179 - val_auc: 0.9853 - val_loss: 0.1905 - learning_rate: 3.0000e-04
# Epoch 24/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 993ms/step - accuracy: 0.9303 - auc: 0.9718 - loss: 0.1876 - val_accuracy: 0.9408 - val_auc: 0.9869 - val_loss: 0.1507 - learning_rate: 3.0000e-04
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 64s 972ms/step - accuracy: 0.9210 - auc: 0.9725 - loss: 0.1845 - val_accuracy: 0.9389 - val_auc: 0.9857 - val_loss: 0.1516 - learning_rate: 3.0000e-04
# Restoring model weights from the end of the best epoch: 24.
# Test Loss: 0.4145
# Test Accuracy: 0.8381
# AUC: 0.9345
#
# === SEMILLA 1 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.7686 - auc: 0.8140 - loss: 0.4750 - val_accuracy: 0.7421 - val_auc: 0.9341 - val_loss: 0.5560 - learning_rate: 0.0010
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 996ms/step - accuracy: 0.8732 - auc: 0.9289 - loss: 0.2992 - val_accuracy: 0.8739 - val_auc: 0.9532 - val_loss: 0.5777 - learning_rate: 0.0010
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8983 - auc: 0.9510 - loss: 0.2459 - val_accuracy: 0.8672 - val_auc: 0.9411 - val_loss: 0.4366 - learning_rate: 0.0010
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 866ms/step - accuracy: 0.8963 - auc: 0.9504 - loss: 0.2478
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8964 - auc: 0.9504 - loss: 0.2478 - val_accuracy: 0.8902 - val_auc: 0.9462 - val_loss: 0.3978 - learning_rate: 0.0010
# Epoch 5/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9070 - auc: 0.9588 - loss: 0.2280 - val_accuracy: 0.8730 - val_auc: 0.9351 - val_loss: 0.3287 - learning_rate: 3.0000e-04
# Epoch 6/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8975 - auc: 0.9504 - loss: 0.2481 - val_accuracy: 0.8921 - val_auc: 0.9576 - val_loss: 0.2928 - learning_rate: 3.0000e-04
# Epoch 7/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 995ms/step - accuracy: 0.9120 - auc: 0.9656 - loss: 0.2067 - val_accuracy: 0.9016 - val_auc: 0.9613 - val_loss: 0.2656 - learning_rate: 3.0000e-04
# Epoch 8/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.
25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 868ms/step - accuracy: 0.9294 - auc: 0.9734 - loss: 0.1810
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9294 - auc: 0.9734 - loss: 0.1811 - val_accuracy: 0.9236 - val_auc: 0.9818 - val_loss: 0.1795 - learning_rate: 2.7000e-05
# Restoring model weights from the end of the best epoch: 21.
# Test Loss: 0.3504
# Test Accuracy: 0.8558
# AUC: 0.9381
#
# === SEMILLA 2 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - accuracy: 0.7454 - auc: 0.7810 - loss: 0.4922 - val_accuracy: 0.2875 - val_auc: 0.9159 - val_loss: 0.7067 - learning_rate: 0.0010
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8668 - auc: 0.9316 - loss: 0.2950 - val_accuracy: 0.7268 - val_auc: 0.9543 - val_loss: 0.6375 - learning_rate: 0.0010
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8861 - auc: 0.9396 - loss: 0.2713 - val_accuracy: 0.8873 - val_auc: 0.9461 - val_loss: 0.4445 - learning_rate: 0.0010
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 882ms/step - accuracy: 0.9046 - auc: 0.9510 - loss: 0.2390
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9045 - auc: 0.9511 - loss: 0.2389 - val_accuracy: 0.8825 - val_auc: 0.9365 - val_loss: 0.3526 - learning_rate: 0.0010
# Epoch 5/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9008 - auc: 0.9506 - loss: 0.2425 - val_accuracy: 0.8854 - val_auc: 0.9535 - val_loss: 0.3071 - learning_rate: 3.0000e-04
# Epoch 6/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8988 - auc: 0.9514 - loss: 0.2419 - val_accuracy: 0.9045 - val_auc: 0.9567 - val_loss: 0.2812 - learning_rate: 3.0000e-04
# Epoch 7/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 995ms/step - accuracy: 0.9084 - auc: 0.9611 - loss: 0.2205 - val_accuracy: 0.9207 - val_auc: 0.9704 - val_loss: 0.2348 - learning_rate: 3.0000e-04
# Epoch 8/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8956 - auc: 0.9575 - loss: 0.2315 - val_accuracy: 0.9198 - val_auc: 0.9677 - val_loss: 0.2365 - learning_rate: 3.0000e-04
# Epoch 9/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9038 - auc: 0.9591 - loss: 0.2253
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9039 - auc: 0.9591 - loss: 0.2252 - val_accuracy: 0.9045 - val_auc: 0.9682 - val_loss: 0.2300 - learning_rate: 3.0000e-04
# Epoch 10/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9114 - auc: 0.9586 - loss: 0.2229 - val_accuracy: 0.9226 - val_auc: 0.9762 - val_loss: 0.2012 - learning_rate: 9.0000e-05
# Epoch 11/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9062 - auc: 0.9607 - loss: 0.2191 - val_accuracy: 0.9169 - val_auc: 0.9760 - val_loss: 0.2053 - learning_rate: 9.0000e-05
# Epoch 12/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9115 - auc: 0.9687 - loss: 0.2013 - val_accuracy: 0.9140 - val_auc: 0.9770 - val_loss: 0.2000 - learning_rate: 9.0000e-05
# Epoch 13/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9095 - auc: 0.9639 - loss: 0.2126 - val_accuracy: 0.9160 - val_auc: 0.9781 - val_loss: 0.1947 - learning_rate: 9.0000e-05
# Epoch 14/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9144 - auc: 0.9630 - loss: 0.2109 - val_accuracy: 0.9255 - val_auc: 0.9778 - val_loss: 0.1943 - learning_rate: 9.0000e-05
# Epoch 15/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9158 - auc: 0.9643 - loss: 0.2099 - val_accuracy: 0.9217 - val_auc: 0.9782 - val_loss: 0.1931 - learning_rate: 9.0000e-05
# Epoch 16/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9172 - auc: 0.9707 - loss: 0.1943 - val_accuracy: 0.9179 - val_auc: 0.9779 - val_loss: 0.1929 - learning_rate: 9.0000e-05
# Epoch 17/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 880ms/step - accuracy: 0.9195 - auc: 0.9693 - loss: 0.1915
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9194 - auc: 0.9692 - loss: 0.1918 - val_accuracy: 0.9188 - val_auc: 0.9776 - val_loss: 0.1960 - learning_rate: 9.0000e-05
# Epoch 18/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9195 - auc: 0.9701 - loss: 0.1914 - val_accuracy: 0.9217 - val_auc: 0.9788 - val_loss: 0.1925 - learning_rate: 2.7000e-05
# Epoch 19/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9207 - auc: 0.9687 - loss: 0.1947 - val_accuracy: 0.9217 - val_auc: 0.9790 - val_loss: 0.1907 - learning_rate: 2.7000e-05
# Epoch 20/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9179 - auc: 0.9630 - loss: 0.2082 - val_accuracy: 0.9226 - val_auc: 0.9792 - val_loss: 0.1913 - learning_rate: 2.7000e-05
# Epoch 21/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9142 - auc: 0.9616 - loss: 0.2166 - val_accuracy: 0.9236 - val_auc: 0.9789 - val_loss: 0.1897 - learning_rate: 2.7000e-05
# Epoch 22/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 862ms/step - accuracy: 0.9254 - auc: 0.9682 - loss: 0.1959
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 998ms/step - accuracy: 0.9253 - auc: 0.9682 - loss: 0.1960 - val_accuracy: 0.9255 - val_auc: 0.9791 - val_loss: 0.1883 - learning_rate: 2.7000e-05
# Epoch 23/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9099 - auc: 0.9640 - loss: 0.2114 - val_accuracy: 0.9236 - val_auc: 0.9792 - val_loss: 0.1891 - learning_rate: 1.0000e-05
# Epoch 24/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9255 - auc: 0.9676 - loss: 0.1992 - val_accuracy: 0.9245 - val_auc: 0.9792 - val_loss: 0.1874 - learning_rate: 1.0000e-05
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9103 - auc: 0.9660 - loss: 0.2044 - val_accuracy: 0.9217 - val_auc: 0.9792 - val_loss: 0.1909 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 25.
# Test Loss: 0.4120
# Test Accuracy: 0.8413
# AUC: 0.9289
#
# === SEMILLA 3 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.7836 - auc: 0.8078 - loss: 0.4450 - val_accuracy: 0.2579 - val_auc: 0.9235 - val_loss: 0.7505 - learning_rate: 0.0010
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8549 - auc: 0.9174 - loss: 0.3145 - val_accuracy: 0.8185 - val_auc: 0.9530 - val_loss: 0.5822 - learning_rate: 0.0010
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0
25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9214 - auc: 0.9680 - loss: 0.1949 - val_accuracy: 0.9312 - val_auc: 0.9861 - val_loss: 0.1595 - learning_rate: 1.0000e-05
# Epoch 19/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9065 - auc: 0.9610 - loss: 0.2180 - val_accuracy: 0.9322 - val_auc: 0.9862 - val_loss: 0.1605 - learning_rate: 1.0000e-05
# Epoch 20/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9220 - auc: 0.9697 - loss: 0.1939 - val_accuracy: 0.9322 - val_auc: 0.9862 - val_loss: 0.1599 - learning_rate: 1.0000e-05
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Test Loss: 0.3967
# Test Accuracy: 0.8365
# AUC: 0.9226
#
# === SEMILLA 4 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.7691 - auc: 0.8068 - loss: 0.4579 - val_accuracy: 0.8233 - val_auc: 0.8946 - val_loss: 0.6297 - learning_rate: 0.0010
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8771 - auc: 0.9335 - loss: 0.2868 - val_accuracy: 0.8863 - val_auc: 0.9392 - val_loss: 0.5380 - learning_rate: 0.0010
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8848 - auc: 0.9379 - loss: 0.2737 - val_accuracy: 0.8281 - val_auc: 0.9207 - val_loss: 0.4510 - learning_rate: 0.0010
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8925 - auc: 0.9466 - loss: 0.2592 - val_accuracy: 0.8376 - val_auc: 0.9582 - val_loss: 0.3296 - learning_rate: 0.0010
# Epoch 5/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9062 - auc: 0.9558 - loss: 0.2364 - val_accuracy: 0.8539 - val_auc: 0.9448 - val_loss: 0.3210 - learning_rate: 0.0010
# Epoch 6/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8964 - auc: 0.9517 - loss: 0.2435 - val_accuracy: 0.8720 - val_auc: 0.9616 - val_loss: 0.3068 - learning_rate: 0.0010
# Epoch 7/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9127 - auc: 0.9641 - loss: 0.2113 - val_accuracy: 0.9131 - val_auc: 0.9616 - val_loss: 0.2433 - learning_rate: 0.0010
# Epoch 8/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8964 - auc: 0.9538 - loss: 0.2416 - val_accuracy: 0.8873 - val_auc: 0.9655 - val_loss: 0.2500 - learning_rate: 0.0010
# Epoch 9/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9048 - auc: 0.9586 - loss: 0.2263 - val_accuracy: 0.9322 - val_auc: 0.9733 - val_loss: 0.2181 - learning_rate: 0.0010
# Epoch 10/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9083 - auc: 0.9566 - loss: 0.2331 - val_accuracy: 0.9284 - val_auc: 0.9722 - val_loss: 0.1903 - learning_rate: 0.0010
# Epoch 11/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9132 - auc: 0.9665 - loss: 0.2020 - val_accuracy: 0.9284 - val_auc: 0.9768 - val_loss: 0.1789 - learning_rate: 0.0010
# Epoch 12/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9102 - auc: 0.9623 - loss: 0.2166 - val_accuracy: 0.9150 - val_auc: 0.9768 - val_loss: 0.1950 - learning_rate: 0.0010
# Epoch 13/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9139 - auc: 0.9653 - loss: 0.2086 - val_accuracy: 0.9226 - val_auc: 0.9775 - val_loss: 0.1798 - learning_rate: 0.0010
# Epoch 14/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9170 - auc: 0.9617 - loss: 0.2199 - val_accuracy: 0.8758 - val_auc: 0.9785 - val_loss: 0.2869 - learning_rate: 0.0010
# Epoch 15/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9203 - auc: 0.9679 - loss: 0.2006 - val_accuracy: 0.9236 - val_auc: 0.9808 - val_loss: 0.1820 - learning_rate: 0.0010
# Epoch 16/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 991ms/step - accuracy: 0.9211 - auc: 0.9657 - loss: 0.2052 - val_accuracy: 0.9188 - val_auc: 0.9786 - val_loss: 0.1904 - learning_rate: 0.0010
# Epoch 17/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 860ms/step - accuracy: 0.9236 - auc: 0.9683 - loss: 0.1975
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9236 - auc: 0.9683 - loss: 0.1975 - val_accuracy: 0.9312 - val_auc: 0.9789 - val_loss: 0.1643 - learning_rate: 0.0010
# Epoch 18/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9255 - auc: 0.9699 - loss: 0.1909 - val_accuracy: 0.9217 - val_auc: 0.9795 - val_loss: 0.1829 - learning_rate: 3.0000e-04
# Epoch 19/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 894ms/step - accuracy: 0.9293 - auc: 0.9718 - loss: 0.1860
# Epoch 19: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9293 - auc: 0.9717 - loss: 0.1862 - val_accuracy: 0.9207 - val_auc: 0.9803 - val_loss: 0.1824 - learning_rate: 3.0000e-04
# Epoch 20/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9264 - auc: 0.9735 - loss: 0.1817 - val_accuracy: 0.9236 - val_auc: 0.9803 - val_loss: 0.1829 - learning_rate: 9.0000e-05
# Epoch 21/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.9232 - auc: 0.9676 - loss: 0.1969
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9233 - auc: 0.9676 - loss: 0.1969 - val_accuracy: 0.9236 - val_auc: 0.9799 - val_loss: 0.1805 - learning_rate: 9.0000e-05
# Epoch 22/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9270 - auc: 0.9717 - loss: 0.1844 - val_accuracy: 0.9226 - val_auc: 0.9798 - val_loss: 0.1845 - learning_rate: 2.7000e-05
# Epoch 23/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 858ms/step - accuracy: 0.9279 - auc: 0.9719 - loss: 0.1853
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-05.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 997ms/step - accuracy: 0.9279 - auc: 0.9718 - loss: 0.1853 - val_accuracy: 0.9236 - val_auc: 0.9801 - val_loss: 0.1828 - learning_rate: 2.7000e-05
# Epoch 24/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 992ms/step - accuracy: 0.9253 - auc: 0.9671 - loss: 0.1935 - val_accuracy: 0.9207 - val_auc: 0.9800 - val_loss: 0.1830 - learning_rate: 1.0000e-05
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 993ms/step - accuracy: 0.9332 - auc: 0.9697 - loss: 0.1884 - val_accuracy: 0.9236 - val_auc: 0.9802 - val_loss: 0.1824 - learning_rate: 1.0000e-05
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# Test Loss: 0.3857
# Test Accuracy: 0.8317
# AUC: 0.9315

# %%
# Elegimos semilla
history_resnet = histories_resnet[1] 

# Accuracy
plt.plot(history_resnet.history['accuracy'], label='Entrenamiento')
plt.plot(history_resnet.history['val_accuracy'], label='Validación')
plt.title('Precisión (Accuracy)')
plt.xlabel('Época')
plt.ylabel('Precisión')
plt.legend()
plt.grid(True)
plt.show()

# Loss
plt.plot(history_resnet.history['loss'], label='Entrenamiento')
plt.plot(history_resnet.history['val_loss'], label='Validación')
plt.title('Pérdida (Loss)')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Fine-tuning R**

# %% [markdown]
# #### Siguiendo la estrategia aplicada en modelos anteriores, procedemos a realizar fine-tuning sobre la red ResNet101, desbloqueando una parte de sus capas para permitir que se ajusten al dominio específico de nuestro conjunto de datos.
#
# #### En este caso concreto:
#
# * #### Se descongelan las capas desde la número 300 en adelante, es decir, las últimas 45 capas.
#
# #### Se han hecho muchas pruebas sobre este modelo, pues para mi sorprensa, funcionaba en la mayoria de los casos mejor con todas las capas congeladas que descongelando y permitiendo que aprendiese sobre el dataset específico. Por este motivo, se han descogelado finalmente un número creo que reducido de capas. Aún asi la mejora respecto a feature extraction ha sido ligera. Además el aprendizaje ha mostrado inestabilidad, lo que se puede ver en las gráficas siguientes.
#
# #### Las curvas de validación indican inestabilidad en el rendimiento sobre datos nuevos. El modelo no esta generalizando de forma estable.
# * #### Dataset pequeño
# * #### Learning rate alto
#
# #### Además, las variaciones en el loss de validación sugieren que la confianza del modelo en sus predicciones es inconsistente. Posibles solucione serían:
# * #### Reducir ligeramente el learning rate (probar con 5e-6 o incluso 1e-6).
# * #### Aumentar el dropout ligeramente

# %%
def build_resnet_model_ft(img_size=224, learning_rate=1e-5):
    # Modelo base
    base_model_resnet_ft = ResNet101(weights='imagenet', include_top=False, input_shape=(img_size, img_size, 3))
    base_model_resnet_ft.trainable = True
    for layer in base_model_resnet_ft.layers[:300]:
        layer.trainable = False

    # Top model
    x = base_model_resnet_ft.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.4)(x)
    x = BatchNormalization()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.2)(x)
    output = Dense(1, activation='sigmoid')(x)  
    
    model_resnet_ft = Model(inputs=base_model_resnet_ft.input, outputs=output)
    
    model_resnet_ft.compile(
        loss='binary_crossentropy',
        optimizer=Adam(learning_rate=1e-5),
        metrics=['accuracy', AUC(name='auc')]
    )
    return model_resnet_ft

model_resnet_ft = build_resnet_model_ft()
model_resnet_ft.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_pad (ZeroPadding2D) │ (None, 230, 230, 3)    │              0 │ input_layer_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_conv (Conv2D)       │ (None, 112, 112, 64)   │          9,472 │ conv1_pad[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_bn                  │ (None, 112, 112, 64)   │            256 │ conv1_conv[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_relu (Activation)   │ (None, 112, 112, 64)   │              0 │ conv1_bn[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool1_pad (ZeroPadding2D) │ (None, 114, 114, 64)   │              0 │ conv1_relu[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool1_pool (MaxPooling2D) │ (None, 56, 56, 64)     │              0 │ pool1_pad[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_conv       │ (None, 56, 56, 64)     │          4,160 │ pool1_pool[0][0]       │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_bn         │ (None, 56, 56, 64)     │            256 │ conv2_block1_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_relu       │ (None, 56, 56, 64)     │              0 │ conv2_block1_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_2_conv       │ (None, 56, 56, 64)     │         36,928 │ conv2_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_2_bn         │ (None, 56, 56, 64)     │            256 │ conv2_block1_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1
3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_out          │ (None, 14, 14, 1024)   │              0 │ conv4_block5_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_1_conv       │ (None, 14, 14, 256)    │        262,400 │ conv4_block5_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_1_bn         │ (None, 14, 14, 256)    │          1,024 │ conv4_block6_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_1_relu       │ (None, 14, 14, 256)    │              0 │ conv4_block6_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_2_conv       │ (None, 14, 14, 256)    │        590,080 │ conv4_block6_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_2_bn         │ (None, 14, 14, 256)    │          1,024 │ conv4_block6_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_2_relu       │ (None, 14, 14, 256)    │              0 │ conv4_block6_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_3_conv       │ (None, 14, 14, 1024)   │        263,168 │ conv4_block6_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_3_bn         │ (None, 14, 14, 1024)   │          4,096 │ conv4_block6_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_add (Add)    │ (None, 14, 14, 1024)   │              0 │ conv4_block5_out[0][0… │
# │                           │                        │                │ conv4_block6_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_out          │ (None, 14, 14, 1024)   │              0 │ conv4_block6_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_1_conv       │ (None, 14, 14, 256)    │        262,400 │ conv4_block6_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_1_bn         │ (None, 14, 14, 256)    │          1,024 │ conv4_block7_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_1_relu       │ (None, 14, 14, 256)    │              0 │ conv4_block7_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_2_conv       │ (None, 14, 14, 256)    │        590,080 │ conv4_block7_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_2_bn         │ (None, 14, 14, 256)    │          1,024 │ conv4_block7_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_2_relu       │ (None, 14, 14, 256)    │              0 │ conv4_block7_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_3_conv       │ (None, 14, 14, 1024)   │        263,168 │ conv4_block7_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_3_bn         │ (None, 14, 14, 1024)   │          4,096 │ conv4_block7_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_add (Add)    │ (None, 14, 14, 1024)   │              0 │ conv4_block6_out[0][0… │
# │                           │                        │                │ conv4_block7_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block7_out          │ (None, 14, 14, 1024)   │              0 │ conv4_block7_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_1_conv       │ (None, 14, 14, 256)    │        262,400 │ conv4_block7_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_1_bn         │ (None, 14, 14, 256)    │          1,024 │ conv4_block8_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_1_relu       │ (None, 14, 14, 256)    │              0 │ conv4_block8_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_2_conv       │ (None, 14, 14, 256)    │        590,080 │ conv4_block8_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_2_bn         │ (None, 14, 14, 256)    │          1,024 │ conv4_block8_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_2_relu       │ (None, 14, 14, 256)    │              0 │ conv4_block8_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_3_conv       │ (None, 14, 14, 1024)   │        263,168 │ conv4_block8_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_3_bn         │ (None, 14, 14, 1024)   │          4,096 │ conv4_block8_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_add (Add)    │ (None, 14, 14, 1024)   │              0 │ conv4_block7_out[0][0… │
# │                           │                        │                │ conv4_block8_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block8_out          │ (None, 14, 14, 1024)   │              0 │ conv4_block8_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block9_1_conv       │ (None, 14, 14, 256)    │        262,400 │ conv4_block8_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block9_1_bn         │ (None, 14, 14, 256)    │          1,024 │ conv4_block9_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block9_1_relu       │ (None, 14, 14, 256)    │              0 │ conv4_block9_1_bn[0][… │
# ...
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block22_3_conv      │ (None, 14, 14, 1024)   │        263,168 │ conv4_block22_2_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block22_3_bn        │ (None, 14, 14, 1024)   │          4,096 │ conv4_block22_3_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block22_add (Add)   │ (None, 14, 14, 1024)   │              0 │ conv4_block21_out[0][… │
# │                           │                        │                │ conv4_block22_3_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block22_out         │ (None, 14, 14, 1024)   │              0 │ conv4_block22_add[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block23_1_conv      │ (None, 14, 14, 256)    │        262,400 │ conv4_block22_out[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block23_1_bn        │ (None, 14, 14, 256)    │          1,024 │ conv4_block23_1_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block23_1_relu      │ (None, 14, 14, 256)    │              0 │ conv4_block23_1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block23_2_conv      │ (None, 14, 14, 256)    │        590,080 │ conv4_block23_1_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block23_2_bn        │ (None, 14, 14, 256)    │          1,024 │ conv4_block23_2_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block23_2_relu      │ (None, 14, 14, 256)    │              0 │ conv4_block23_2_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block23_3_conv      │ (None, 14, 14, 1024)   │        263,168 │ conv4_block23_2_relu[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block23_3_bn        │ (None, 14, 14, 1024)   │          4,096 │ conv4_block23_3_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block23_add (Add)   │ (None, 14, 14, 1024)   │              0 │ conv4_block22_out[0][… │
# │                           │                        │                │ conv4_block23_3_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block23_out         │ (None, 14, 14, 1024)   │              0 │ conv4_block23_add[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1

# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 43,233,153 (164.92 MB)
#  Trainable params: 16,667,137 (63.58 MB)
#  Non-trainable params: 26,566,016 (101.34 MB)

# %% [markdown]
# **Resumen arquitectura:**
#
# Total params: 43,233,153 (164.92 MB)
#
# Trainable params: 16,667,137 (63.58 MB)
#
# Non-trainable params: 26,566,016 (101.34 MB)

# %%
img_size = 150
batch_size = 64
learning_rate=1e-5
seeds = [0, 1, 2, 3, 4]

results_resnet_ft_list = []
histories_resnet_ft = {}
models_resnet_ft = {}

test_paths, test_labels = get_image_paths_labels(test_dir)
test_df = pd.DataFrame({'filename': test_paths, 'label': test_labels})

for seed in seeds:
    print(f"\n=== SEMILLA {seed} ===")

    tf.random.set_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    
    # Preparar datos
    train_df, val_df = get_dataframes(train_dir, val_dir, seed)
    train_generator, val_generator, test_generator = get_data_generators(train_df, val_df, test_df, img_size, batch_size, seed)
    
    # Ajuste de pesos
    class_weights = get_class_weights(train_df)
    
    # Crear modelo Custom CNN
    model_resnet_ft = build_resnet_model_ft(img_size, learning_rate)
    
    # Callbacks
    callbacks = get_callbacks()
    
    # Entrenamiento
    history_resnet_ft = model_resnet_ft.fit(
        train_generator,
        validation_data=val_generator,
        epochs=25,
        class_weight=class_weights,
        callbacks=callbacks,
    )

    histories_resnet_ft[seed] = history_resnet_ft
    models_resnet_ft[seed] = model_resnet_ft
    
    # Evaluación en test
    results_resnet_ft = model_resnet_ft.evaluate(test_generator, verbose=0)
    print(f"Test Loss: {results_resnet_ft[0]:.4f}")
    print(f"Test Accuracy: {results_resnet_ft[1]:.4f}")
    print(f"AUC: {results_resnet_ft[2]:.4f}")
    
    # Guardar resultados
    results_resnet_ft_list.append({
        'Seed': seed,
        'Test Loss': results_resnet_ft[0],
        'Test Accuracy': results_resnet_ft[1],
        'Test AUC': results_resnet_ft[2]
    })

# Mostramos resultados
df_results_resnet_ft = pd.DataFrame(results_resnet_ft_list)

plt.figure(figsize=(8, 6))
sns.boxplot(data=df_results_resnet_ft[['Test Accuracy', 'Test AUC', 'Test Loss']])
plt.title('Distribución de métricas en test (5 semillas) - Resnet101 (FT)')
plt.grid(True)
plt.show()
# Out:
# === SEMILLA 0 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 135s 1s/step - accuracy: 0.7496 - auc: 0.6648 - loss: 0.5623 - val_accuracy: 0.7421 - val_auc: 0.3550 - val_loss: 0.5849 - learning_rate: 1.0000e-05
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8393 - auc: 0.8900 - loss: 0.3582 - val_accuracy: 0.7421 - val_auc: 0.7449 - val_loss: 0.5565 - learning_rate: 1.0000e-05
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8620 - auc: 0.9077 - loss: 0.3323 - val_accuracy: 0.7421 - val_auc: 0.7442 - val_loss: 0.5537 - learning_rate: 1.0000e-05
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8695 - auc: 0.9247 - loss: 0.3003 - val_accuracy: 0.7421 - val_auc: 0.8467 - val_loss: 0.5402 - learning_rate: 1.0000e-05
# Epoch 5/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8951 - auc: 0.9451 - loss: 0.2620 - val_accuracy: 0.8367 - val_auc: 0.9581 - val_loss: 0.3797 - learning_rate: 1.0000e-05
# Epoch 6/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9051 - auc: 0.9532 - loss: 0.2494 - val_accuracy: 0.9007 - val_auc: 0.9764 - val_loss: 0.3025 - learning_rate: 1.0000e-05
# Epoch 7/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8991 - auc: 0.9524 - loss: 0.2409 - val_accuracy: 0.8730 - val_auc: 0.9782 - val_loss: 0.3162 - learning_rate: 1.0000e-05
# Epoch 8/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9133 - auc: 0.9609 - loss: 0.2222 - val_accuracy: 0.9093 - val_auc: 0.9815 - val_loss: 0.2509 - learning_rate: 1.0000e-05
# Epoch 9/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9090 - auc: 0.9523 - loss: 0.2460 - val_accuracy: 0.9465 - val_auc: 0.9848 - val_loss: 0.1592 - learning_rate: 1.0000e-05
# Epoch 10/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9082 - auc: 0.9641 - loss: 0.2136 - val_accuracy: 0.9389 - val_auc: 0.9833 - val_loss: 0.1778 - learning_rate: 1.0000e-05
# Epoch 11/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9192 - auc: 0.9668 - loss: 0.2067 - val_accuracy: 0.7421 - val_auc: 0.9831 - val_loss: 0.5926 - learning_rate: 1.0000e-05
# Epoch 12/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9120 - auc: 0.9607 - loss: 0.2255 - val_accuracy: 0.5330 - val_auc: 0.9648 - val_loss: 1.3010 - learning_rate: 1.0000e-05
# Epoch 13/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9232 - auc: 0.9723 - loss: 0.1844 - val_accuracy: 0.8711 - val_auc: 0.9857 - val_loss: 0.3597 - learning_rate: 1.0000e-05
# Epoch 14/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9232 - auc: 0.9666 - loss: 0.2011 - val_accuracy: 0.9570 - val_auc: 0.9894 - val_loss: 0.1258 - learning_rate: 1.0000e-05
# Epoch 15/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9368 - auc: 0.9757 - loss: 0.1759 - val_accuracy: 0.9274 - val_auc: 0.9910 - val_loss: 0.1639 - learning_rate: 1.0000e-05
# Epoch 16/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9254 - auc: 0.9708 - loss: 0.1942 - val_accuracy: 0.9188 - val_auc: 0.9887 - val_loss: 0.2145 - learning_rate: 1.0000e-05
# Epoch 17/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9272 - auc: 0.9702 - loss: 0.1930 - val_accuracy: 0.9542 - val_auc: 0.9896 - val_loss: 0.1150 - learning_rate: 1.0000e-05
# Epoch 18/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9322 - auc: 0.9696 - loss: 0.1953 - val_accuracy: 0.9351 - val_auc: 0.9911 - val_loss: 0.1626 - learning_rate: 1.0000e-05
# Epoch 19/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9352 - auc: 0.9708 - loss: 0.1836 - val_accuracy: 0.7813 - val_auc: 0.9886 - val_loss: 0.5151 - learning_rate: 1.0000e-05
# Epoch 20/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9314 - auc: 0.9751 - loss: 0.1752 - val_accuracy: 0.9102 - val_auc: 0.9901 - val_loss: 0.2189 - learning_rate: 1.0000e-05
# Epoch 21/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9262 - auc: 0.9699 - loss: 0.1884 - val_accuracy: 0.5941 - val_auc: 0.9726 - val_loss: 1.1542 - learning_rate: 1.0000e-05
# Epoch 22/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9309 - auc: 0.9731 - loss: 0.1847 - val_accuracy: 0.9016 - val_auc: 0.9866 - val_loss: 0.2760 - learning_rate: 1.0000e-05
# Epoch 23/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9336 - auc: 0.9727 - loss: 0.1805 - val_accuracy: 0.7373 - val_auc: 0.9729 - val_loss: 0.8241 - learning_rate: 1.0000e-05
# Epoch 24/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9241 - auc: 0.9728 - loss: 0.1839 - val_accuracy: 0.9351 - val_auc: 0.9917 - val_loss: 0.1680 - learning_rate: 1.0000e-05
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9272 - auc: 0.9729 - loss: 0.1832 - val_accuracy: 0.8481 - val_auc: 0.9916 - val_loss: 0.3692 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 24.
# Test Loss: 0.3250
# Test Accuracy: 0.8926
# AUC: 0.9454
#
# === SEMILLA 1 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 0.5673 - auc: 0.7017 - loss: 0.7729 - val_accuracy: 0.2579 - val_auc: 0.5440 - val_loss: 0.7716 - learning_rate: 1.0000e-05
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.7552 - auc: 0.8454 - loss: 0.5199 - val_accuracy: 0.2818 - val_auc: 0.4767 - val_loss: 0.7314 - learning_rate: 1.0000e-05
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8415 - auc: 0.9146 - loss: 0.3797 - val_accuracy: 0.6294 - val_auc: 0.5998 - val_loss: 0.6864 - learning_rate: 1.0000e-05
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8556 - auc: 0.9151 - loss: 0.3484 - val_accuracy: 0.7813 - val_auc: 0.8910 - val_loss: 0.5351 - learning_rate: 1.0000e-05
# Epoch 5/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8830 - auc: 0.9388 - loss: 0.3066 - val_accuracy: 0.8395 - val_auc: 0.9154 - val_loss: 0.4211 - learning_rate: 1.0000e-05
# Epoch 6/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8773 - auc: 0.9259 - loss: 0.3197 - val_accuracy: 0.9083 - val_auc: 0.9503 - val_loss: 0.3991 - learning_rate: 1.0000e-05
# Epoch 7/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9018 - auc: 0.9534 - loss: 0.2590 - val_accuracy: 0.9293 - val_auc: 0.9750 - val_loss: 0.2365 - learning_rate: 1.0000e-05
# Epoch 8/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.8970 - auc: 0.9485 - loss: 0.2617 - val_accuracy: 0.9150 - val_auc: 0.9779 - val_loss: 0.2201 - learning_rate: 1.0000e-05
# Epoch 9/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9097 - auc: 0.9608 - loss: 0.2328 - val_accuracy: 0.9417 - val_auc: 0.9779 - val_loss: 0.1760 - learning_rate: 1.0000e-05
# Epoch 10/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9146 - auc: 0.9615 - loss: 0.2332 - val_accuracy: 0.9484 - val_auc: 0.9766 - val_loss: 0.1619 - learning_rate: 1.0000e-05
# Epoch 11/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9244 - auc: 0.9628 - loss: 0.2183 - val_accuracy: 0.9494 - val_auc: 0.9767 - val_loss: 0.1523 - learning_rate: 1.0000e-05
# Epoch 12/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9073 - auc: 0.9587 - loss: 0.2334 - val_accuracy: 0.8185 - val_auc: 0.9776 - val_loss: 0.4965 - learning_rate: 1.0000e-05
# Epoch 13/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9176 - auc: 0.9668 - loss: 0.2157 - val_accuracy: 0.9303 - val_auc: 0.9820 - val_loss: 0.1809 - learning_rate: 1.0000e-05
# Epoch 14/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9221 - auc: 0.9661 - loss: 0.2044 - val_accuracy: 0.9112 - val_auc: 0.9853 - val_loss: 0.2276 - learning_rate: 1.0000e-05
# Epoch 15/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9146 - auc: 0.9604 - loss: 0.2248 - val_accuracy: 0.9351 - val_auc: 0.9794 - val_loss: 0.1748 - learning_rate: 1.0000e-05
# Epoch 16/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9380 - auc: 0.9766 - loss: 0.1745 - val_accuracy: 0.9274 - val_auc: 0.9868 - val_loss: 0.1961 - learning_rate: 1.0000e-05
# Epoch 17/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9330 - auc: 0.9732 - loss: 0.1870 - val_accuracy: 0.9427 - val_auc: 0.9876 - val_loss: 0.1392 - learning_rate: 1.0000e-05
# Epoch 18/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9252 - auc: 0.9675 - loss: 0.2024 - val_accuracy: 0.8949 - val_auc: 0.9860 - val_loss: 0.2995 - learning_rate: 1.0000e-05
# Epoch 19/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9250 - auc: 0.9665 - loss: 0.2058 - val_accuracy: 0.9570 - val_auc: 0.9845 - val_loss: 0.1357 - learning_rate: 1.0000e-05
# Epoch 20/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9263 - auc: 0.9681 - loss: 0.2001 - val_accuracy: 0.9503 - val_auc: 0.9830 - val_loss: 0.1392 - learning_rate: 1.0000e-05
# Epoch 21/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9356 - auc: 0.9735 - loss: 0.1858 - val_accuracy: 0.8376 - val_auc: 0.9821 - val_loss: 0.4600 - learning_rate: 1.0000e-05
# Epoch 22/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9365 - auc: 0.9749 - loss: 0.1752 - val_accuracy: 0.9140 - val_auc: 0.9889 - val_loss: 0.2292 - learning_rate: 1.0000e-05
# Epoch 23/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9363 - auc: 0.9758 - loss: 0.1713 - val_accuracy: 0.9532 - val_auc: 0.9897 - val_loss: 0.1157 - learning_rate: 1.0000e-05
# Epoch 24/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - accuracy: 0.9271 - auc: 0.9692 - loss: 0.1926 - val_accuracy: 0.9150 - val_auc: 0.9860 - val_loss: 0.2311 - learning_rate: 1.0000e-05
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 992ms/step - accuracy: 0.9377 - auc: 0.9776 - loss: 0.1651 - val_accuracy: 0.8940 - val_auc: 0.9894 - val_loss: 0.2911 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 23.
# Test Loss: 0.4712
# Test Accuracy: 0.7853
# AUC: 0.9457
#
# === SEMILLA 2 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 128s 1s/step - accuracy: 0.5378 - auc: 0.6714 - loss: 0.8136 - val_accuracy: 0.5377 - val_auc: 0.5158 - val_loss: 0.6910 - learning_rate: 1.0000e-05
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 65s 986ms/step - accuracy: 0.7796 - auc: 0.8801 - loss: 0.4819 - val_accuracy: 0.4518 - val_auc: 0.5825 - val_loss: 0.7052 - learning_rate: 1.0000e-05
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8350 - auc: 0.9006 - loss: 0.3965 - val_accuracy: 0.6275 - val_auc: 0.7260 - val_loss: 0.6574 - learning_rate: 1.0000e-05
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 65s 990ms/step - accuracy: 0.8778 - auc: 0.9341 - loss: 0.3163 - val_accuracy: 0.8539 - val_auc: 0.8404 - val_loss: 0.5464 - learning_rate: 1.0000e-05
# Epoch 5/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 996ms/step - accuracy: 0.8859 - auc: 0.9376 - loss: 0.3023 - val_accuracy: 0.8854 - val_auc: 0.9167 - val_loss: 0.3724 - learning_rate: 1.0000e-05
# Epoch 6/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8934 - auc: 0.9426 - loss: 0.2812 - val_accuracy: 0.9150 - val_auc: 0.9709 - val_loss: 0.2774 - learning_rate: 1.0000e-05
# Epoch 7/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 65s 990ms/step - accuracy: 0.9078 - auc: 0.9574 - loss: 0.2423 - val_accuracy: 0.9131 - val_auc: 0.9772 - val_loss: 0.2323 - learning_rate: 1.0000e-05
# Epoch 8/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8977 - auc: 0.9520 - loss: 0.2576 - val_accuracy: 0.8586 - val_auc: 0.9788 - val_loss: 0.3281 - learning_rate: 1.0000e-05
# Epoch 9/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9175 - auc: 0.9582 - loss: 0.2351 - val_accuracy: 0.9045 - val_auc: 0.9796 - val_loss: 0.2432 - learning_rate: 1.0000e-05
# Epoch 10/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9148 - auc: 0.9602 - loss: 0.2219 - val_accuracy: 0.8500 - val_auc: 0.9825 - val_loss: 0.3359 - learning_rate: 1.0000e-05
# Epoch 11/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9137 - auc: 0.9623 - loss: 0.2232 - val_accuracy: 0.9417 - val_auc: 0.9834 - val_loss: 0.1550 - learning_rate: 1.0000e-05
# Epoch 12/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 998ms/step - accuracy: 0.9146 - auc: 0.9613 - loss: 0.2229 - val_accuracy: 0.9217 - val_auc: 0.9738 - val_loss: 0.1917 - learning_rate: 1.0000e-05
# Epoch 13/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9254 - auc: 0.9647 - loss: 0.2102 - val_accuracy: 0.8787 - val_auc: 0.9857 - val_loss: 0.2928 - learning_rate: 1.0000e-05
# Epoch 14/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9239 - auc: 0.9674 - loss: 0.2026 - val_accuracy: 0.6991 - val_auc: 0.9743 - val_loss: 0.8370 - learning_rate: 1.0000e-05
# Epoch 15/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9247 - auc: 0.9673 - loss: 0.2015 - val_accuracy: 0.8491 - val_auc: 0.9894 - val_loss: 0.3382 - learning_rate: 1.0000e-05
# Epoch 16/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9307 - auc: 0.9715 - loss: 0.1833 - val_accuracy: 0.8949 - val_auc: 0.9876 - val_loss: 0.2511 - learning_rate: 1.0000e-05
# Epoch 17/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9334 - auc: 0.9740 - loss: 0.1795 - val_accuracy: 0.9542 - val_auc: 0.9869 - val_loss: 0.1442 - learning_rate: 1.0000e-05
# Epoch 18/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9408 - auc: 0.9752 - loss: 0.1717 - val_accuracy: 0.9484 - val_auc: 0.9868 - val_loss: 0.1496 - learning_rate: 1.0000e-05
# Epoch 19/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9340 - auc: 0.9784 - loss: 0.1683 - val_accuracy: 0.9093 - val_auc: 0.9855 - val_loss: 0.2538 - learning_rate: 1.0000e-05
# Epoch 20/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9357 - auc: 0.9722 - loss: 0.1793 - val_accuracy: 0.9427 - val_auc: 0.9866 - val_loss: 0.1473 - learning_rate: 1.0000e-05
# Epoch 21/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9186 - auc: 0.9694 - loss: 0.1980 - val_accuracy: 0.9456 - val_auc: 0.9855 - val_loss: 0.1423 - learning_rate: 1.0000e-05
# Epoch 22/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9364 - auc: 0.9747 - loss: 0.1760 - val_accuracy: 0.9265 - val_auc: 0.9815 - val_loss: 0.1753 - learning_rate: 1.0000e-05
# Epoch 23/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9212 - auc: 0.9678 - loss: 0.2028 - val_accuracy: 0.9064 - val_auc: 0.9871 - val_loss: 0.2210 - learning_rate: 1.0000e-05
# Epoch 24/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9296 - auc: 0.9749 - loss: 0.1758 - val_accuracy: 0.9112 - val_auc: 0.9894 - val_loss: 0.1912 - learning_rate: 1.0000e-05
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9316 - auc: 0.9760 - loss: 0.1697 - val_accuracy: 0.8758 - val_auc: 0.9899 - val_loss: 0.2907 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 25.
# Test Loss: 0.2928
# Test Accuracy: 0.8814
# AUC: 0.9454
#
# === SEMILLA 3 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.6743 - auc: 0.7133 - loss: 0.6041 - val_accuracy: 0.6791 - val_auc: 0.6204 - val_loss: 0.6882 - learning_rate: 1.0000e-05
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.7990 - auc: 0.8536 - loss: 0.4452 - val_accuracy: 0.7421 - val_auc: 0.3574 - val_loss: 0.6280 - learning_rate: 1.0000e-05
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.8427 - auc: 0.9039 - loss: 0.3641 - val_accuracy: 0.7421 - val_auc: 0.6606 - val_loss: 0.5830 - learning_rate: 1.0000e-05
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.8660 - auc: 0.9229 - loss: 0.3275 - val_accuracy: 0.7421 - val_auc: 0.8997 - val_loss: 0.4953 - learning_rate: 1.0000e-05
# Epoch 5/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - accuracy: 0.8933 - auc: 0.9428 - loss: 0.2769 - val_accuracy: 0.8357 - val_auc: 0.9645 - val_loss: 0.3597 - learning_rate: 1.0000e-05
# Epoch 6/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8929 - auc: 0.9403 - loss: 0.2736 - val_accuracy: 0.9255 - val_auc: 0.9791 - val_loss: 0.2522 - learning_rate: 1.0000e-05
# Epoch 7/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9134 - auc: 0.9538 - loss: 0.2425 - val_accuracy: 0.8777 - val_auc: 0.9840 - val_loss: 0.3055 - learning_rate: 1.0000e-05
# Epoch 8/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9200 - auc: 0.9637 - loss: 0.2200 - val_accuracy: 0.9561 - val_auc: 0.9888 - val_loss: 0.1499 - learning_rate: 1.0000e-05
# Epoch 9/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9065 - auc: 0.9597 - loss: 0.2273 - val_accuracy: 0.8233 - val_auc: 0.9900 - val_loss: 0.4130 - learning_rate: 1.0000e-05
# Epoch 10/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9317 - auc: 0.9668 - loss: 0.2005 - val_accuracy: 0.8930 - val_auc: 0.9908 - val_loss: 0.2608 - learning_rate: 1.0000e-05
# Epoch 11/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9206 - auc: 0.9629 - loss: 0.2134 - val_accuracy: 0.9322 - val_auc: 0.9921 - val_loss: 0.1541 - learning_rate: 1.0000e-05
# Epoch 12/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9214 - auc: 0.9669 - loss: 0.1971 - val_accuracy: 0.8978 - val_auc: 0.9904 - val_loss: 0.2729 - learning_rate: 1.0000e-05
# Epoch 13/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9166 - auc: 0.9642 - loss: 0.2127 - val_accuracy: 0.9274 - val_auc: 0.9867 - val_loss: 0.1799 - learning_rate: 1.0000e-05
# Epoch 14/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9327 - auc: 0.9697 - loss: 0.1909 - val_accuracy: 0.9503 - val_auc: 0.9865 - val_loss: 0.1417 - learning_rate: 1.0000e-05
# Epoch 15/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9196 - auc: 0.9692 - loss: 0.1943 - val_accuracy: 0.8720 - val_auc: 0.9907 - val_loss: 0.3099 - learning_rate: 1.0000e-05
# Epoch 16/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9256 - auc: 0.9736 - loss: 0.1879 - val_accuracy: 0.9207 - val_auc: 0.9938 - val_loss: 0.2032 - learning_rate: 1.0000e-05
# Epoch 17/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9285 - auc: 0.9718 - loss: 0.1905 - val_accuracy: 0.9408 - val_auc: 0.9939 - val_loss: 0.1465 - learning_rate: 1.0000e-05
# Epoch 18/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9326 - auc: 0.9698 - loss: 0.1837 - val_accuracy: 0.9599 - val_auc: 0.9907 - val_loss: 0.1141 - learning_rate: 1.0000e-05
# Epoch 19/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9220 - auc: 0.9710 - loss: 0.1932 - val_accuracy: 0.9542 - val_auc: 0.9943 - val_loss: 0.1117 - learning_rate: 1.0000e-05
# Epoch 20/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9322 - auc: 0.9740 - loss: 0.1788 - val_accuracy: 0.9255 - val_auc: 0.9943 - val_loss: 0.1926 - learning_rate: 1.0000e-05
# Epoch 21/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9247 - auc: 0.9690 - loss: 0.1951 - val_accuracy: 0.9580 - val_auc: 0.9921 - val_loss: 0.1159 - learning_rate: 1.0000e-05
# Epoch 22/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9242 - auc: 0.9697 - loss: 0.1860 - val_accuracy: 0.9628 - val_auc: 0.9936 - val_loss: 0.0919 - learning_rate: 1.0000e-05
# Epoch 23/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9339 - auc: 0.9759 - loss: 0.1730 - val_accuracy: 0.9608 - val_auc: 0.9939 - val_loss: 0.0992 - learning_rate: 1.0000e-05
# Epoch 24/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9256 - auc: 0.9733 - loss: 0.1851 - val_accuracy: 0.9599 - val_auc: 0.9948 - val_loss: 0.0986 - learning_rate: 1.0000e-05
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9291 - auc: 0.9745 - loss: 0.1821 - val_accuracy: 0.9551 - val_auc: 0.9920 - val_loss: 0.1032 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 24.
# Test Loss: 0.3531
# Test Accuracy: 0.8622
# AUC: 0.9574
#
# === SEMILLA 4 ===
# Found 4185 validated image filenames belonging to 2 classes.
# Found 1047 validated image filenames belonging to 2 classes.
# Found 624 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 127s 1s/step - accuracy: 0.6634 - auc: 0.7110 - loss: 0.6166 - val_accuracy: 0.4021 - val_auc: 0.3716 - val_loss: 0.6924 - learning_rate: 1.0000e-05
# Epoch 2/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8233 - auc: 0.8768 - loss: 0.4144 - val_accuracy: 0.4594 - val_auc: 0.5410 - val_loss: 0.6942 - learning_rate: 1.0000e-05
# Epoch 3/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 999ms/step - accuracy: 0.8567 - auc: 0.9098 - loss: 0.3469 - val_accuracy: 0.7517 - val_auc: 0.8326 - val_loss: 0.6019 - learning_rate: 1.0000e-05
# Epoch 4/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8819 - auc: 0.9322 - loss: 0.2966 - val_accuracy: 0.7431 - val_auc: 0.9286 - val_loss: 0.5912 - learning_rate: 1.0000e-05
# Epoch 5/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8828 - auc: 0.9308 - loss: 0.2954 - val_accuracy: 0.9035 - val_auc: 0.9558 - val_loss: 0.4128 - learning_rate: 1.0000e-05
# Epoch 6/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.8905 - auc: 0.9477 - loss: 0.2632 - val_accuracy: 0.8997 - val_auc: 0.9658 - val_loss: 0.2832 - learning_rate: 1.0000e-05
# Epoch 7/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9065 - auc: 0.9613 - loss: 0.2319 - val_accuracy: 0.9179 - val_auc: 0.9727 - val_loss: 0.2291 - learning_rate: 1.0000e-05
# Epoch 8/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8977 - auc: 0.9506 - loss: 0.2506 - val_accuracy: 0.9169 - val_auc: 0.9748 - val_loss: 0.2197 - learning_rate: 1.0000e-05
# Epoch 9/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9107 - auc: 0.9596 - loss: 0.2265 - val_accuracy: 0.9322 - val_auc: 0.9799 - val_loss: 0.1725 - learning_rate: 1.0000e-05
# Epoch 10/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9121 - auc: 0.9605 - loss: 0.2213 - val_accuracy: 0.9131 - val_auc: 0.9755 - val_loss: 0.2220 - learning_rate: 1.0000e-05
# Epoch 11/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9323 - auc: 0.9708 - loss: 0.1890 - val_accuracy: 0.9160 - val_auc: 0.9787 - val_loss: 0.2404 - learning_rate: 1.0000e-05
# Epoch 12/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9182 - auc: 0.9656 - loss: 0.2087 - val_accuracy: 0.9102 - val_auc: 0.9792 - val_loss: 0.2320 - learning_rate: 1.0000e-05
# Epoch 13/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9261 - auc: 0.9700 - loss: 0.1989 - val_accuracy: 0.8978 - val_auc: 0.9816 - val_loss: 0.2427 - learning_rate: 1.0000e-05
# Epoch 14/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9197 - auc: 0.9662 - loss: 0.2069 - val_accuracy: 0.7660 - val_auc: 0.9782 - val_loss: 0.6242 - learning_rate: 1.0000e-05
# Epoch 15/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9211 - auc: 0.9676 - loss: 0.2009 - val_accuracy: 0.8548 - val_auc: 0.9820 - val_loss: 0.3758 - learning_rate: 1.0000e-05
# Epoch 16/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9316 - auc: 0.9710 - loss: 0.1909 - val_accuracy: 0.8758 - val_auc: 0.9791 - val_loss: 0.3316 - learning_rate: 1.0000e-05
# Epoch 17/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9315 - auc: 0.9733 - loss: 0.1841 - val_accuracy: 0.9035 - val_auc: 0.9864 - val_loss: 0.2385 - learning_rate: 1.0000e-05
# Epoch 18/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9317 - auc: 0.9708 - loss: 0.1906 - val_accuracy: 0.9303 - val_auc: 0.9872 - val_loss: 0.1732 - learning_rate: 1.0000e-05
# Epoch 19/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9321 - auc: 0.9759 - loss: 0.1765 - val_accuracy: 0.9255 - val_auc: 0.9857 - val_loss: 0.1861 - learning_rate: 1.0000e-05
# Epoch 20/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - accuracy: 0.9411 - auc: 0.9763 - loss: 0.1697 - val_accuracy: 0.9446 - val_auc: 0.9851 - val_loss: 0.1390 - learning_rate: 1.0000e-05
# Epoch 21/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9245 - auc: 0.9701 - loss: 0.1923 - val_accuracy: 0.8940 - val_auc: 0.9858 - val_loss: 0.2814 - learning_rate: 1.0000e-05
# Epoch 22/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9368 - auc: 0.9762 - loss: 0.1712 - val_accuracy: 0.7956 - val_auc: 0.9786 - val_loss: 0.5999 - learning_rate: 1.0000e-05
# Epoch 23/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9296 - auc: 0.9776 - loss: 0.1719 - val_accuracy: 0.9341 - val_auc: 0.9845 - val_loss: 0.1667 - learning_rate: 1.0000e-05
# Epoch 24/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9368 - auc: 0.9742 - loss: 0.1719 - val_accuracy: 0.8777 - val_auc: 0.9837 - val_loss: 0.3450 - learning_rate: 1.0000e-05
# Epoch 25/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9328 - auc: 0.9755 - loss: 0.1722 - val_accuracy: 0.8586 - val_auc: 0.9827 - val_loss: 0.4122 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 18.
# Test Loss: 0.3709
# Test Accuracy: 0.8462
# AUC: 0.9254

# %%
# Elegimos semilla
history_resnet_ft = histories_resnet_ft[2] 

# Accuracy
plt.plot(history_resnet_ft.history['accuracy'], label='Entrenamiento')
plt.plot(history_resnet_ft.history['val_accuracy'], label='Validación')
plt.title('Precisión (Accuracy)')
plt.xlabel('Época')
plt.ylabel('Precisión')
plt.legend()
plt.grid(True)
plt.show()

# Loss
plt.plot(history_resnet_ft.history['loss'], label='Entrenamiento')
plt.plot(history_resnet_ft.history['val_loss'], label='Validación')
plt.title('Pérdida (Loss)')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Evaluación del Rendimiento ResNet**

# %% [markdown]
# ### **ResNet101 con Feature Extraction**

# %%
# Elegimos la semilla para ver las métricas de esa ejecución
y_true, y_pred, y_pred_probs = evaluar_modelo(models_resnet[1], test_generator, nombre_modelo="ResNet101 (Feature Extraction)")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step
# Métricas de Clasificación - ResNet101 (Feature Extraction)
#               precision    recall  f1-score   support
#
#       NORMAL       0.90      0.69      0.78       234
#    PNEUMONIA       0.84      0.96      0.89       390
#
#     accuracy                           0.86       624
#    macro avg       0.87      0.82      0.84       624
# weighted avg       0.86      0.86      0.85       624
#
# AUC-ROC: 0.9399
# Especificidad: 0.6880

# %% [markdown]
# #### **Matriz de Confusión:**
# * #### Clasifica correctamente la mayoría de los casos de PNEUMONIA: 373 sobre 390.
# * #### También se clasifican adecuadamente una buena parte de las imágenes NORMALES: 161 aciertos sobre 234.
#
# #### **Métricas de Clasificación:**
#
# #### **1. Precisión**
#
# * #### NORMAL → 0.90. El 90% de las veces que el modelo predice que es normal, acierta.
# * #### PNEUMONIA → 0.84. El 84% de las veces que predice neumonía, acierta.
#
# #### **2. Recall (Sensibilidad)**
#
# * #### NORMAL → 0.69. El modelo detecta correctamente el 69% de las imágenes normales.
# * #### PNEUMONIA →  0.96. El modelo identifica correctamente el 96% de los casos con neumonía, lo cual es muy relevante en diagnóstico médico.
#
# #### **3. F1-Score**
#  * #### Buen equilibrio entre precisión y sensibilidad, especialmente alto en la clase neumonía (0.89), lo que refuerza su utilidad diagnóstica.
#
# #### **4. Accuracy**
# * #### Precisión global del modelo: 0.86. Aunque es un valor razonable, es algo inferior al de otros modelos probados, lo que indica margen de mejora.
#
# #### **AUC-ROC (0.9399):** Indica excelente capacidad del modelo para distinguir entre ambas clases. Cuanto más cerca de 1, mejor.
#
# #### **Especificidad (0.6880):** Mide la capacidad del modelo para identificar correctamente los casos normales. Este valor, al ser notablemente más bajo que el recall de la clase neumonía, sugiere que el modelo tiende a clasificar más falsos positivos en la clase neumonía, algo común en modelos que priorizan la detección de casos enfermos sobre los sanos.

# %% [markdown]
# ### **ResNet101 con Fine-Tuning**

# %%
# Elegimos la semilla para ver las métricas de esa ejecución
y_true, y_pred, y_pred_probs = evaluar_modelo(models_resnet_ft[2], test_generator, nombre_modelo="ResNet101 (Fine-Tuning)")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step
# Métricas de Clasificación - ResNet101 (Feature Extraction)
#               precision    recall  f1-score   support
#
#       NORMAL       0.84      0.85      0.84       234
#    PNEUMONIA       0.91      0.90      0.90       390
#
#     accuracy                           0.88       624
#    macro avg       0.87      0.87      0.87       624
# weighted avg       0.88      0.88      0.88       624
#
# AUC-ROC: 0.9455
# Especificidad: 0.8462

# %% [markdown]
# #### **Matriz de Confusión:**
# * #### Clasifica correctamente la mayoría de los casos de PNEUMONIA: 352 sobre 390.
# * #### También se clasifican adecuadamente la mayoría de las imágenes NORMALES: 198 aciertos sobre 234.
#
# #### **Métricas de Clasificación:**
#
# #### **1. Precisión**
#
# * #### NORMAL → 0.84. El 84% de las veces que el modelo predice que es normal, acierta.
# * #### PNEUMONIA → 0.91. El 91% de las veces que predice neumonía, acierta.
#
# #### **2. Recall (Sensibilidad)**
#
# * #### NORMAL → 0.85. El modelo detecta correctamente el 85% de las imágenes normales.
# * #### PNEUMONIA →  0.90. El modelo identifica correctamente el 90% de los casos con neumonía, lo cual es un resultado sólido para diagnóstico médico.
#
# #### **3. F1-Score**
#  * #### Buen equilibrio entre precisión y sensibilidad, destacando la clase neumonía (0.90), lo que refuerza su utilidad diagnóstica.
#
# #### **4. Accuracy**
# * #### Precisión global del modelo: 0.88. Es un valor alto y consistente. Dado que el dataset está balanceado, esta métrica es representativa.
#
# #### **AUC-ROC (0.9455):** Indica excelente capacidad del modelo para distinguir entre ambas clases. Cuanto más cerca de 1, mejor.
#
# #### **Especificidad (0.8462):** Mide la capacidad del modelo para identificar correctamente los casos normales. Este valor, aunque algo inferior al recall de la clase neumonía, muestra un buen equilibrio, lo que sugiere que el modelo no presenta un sesgo acusado hacia ninguna de las dos clases.
